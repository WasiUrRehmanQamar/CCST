# %% [markdown]
# # **Use GPU**

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # **Hide Warnings**

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Install Libraries**

# %%
pip install torch torchvision torchaudio torchinfo einops scikit-learn pandas
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.11/dist-packages (1.8.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (0.8.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U mne==1.0.0 scipy==1.13.1 numpy==1.26.4
# Out:
# Requirement already satisfied: mne==1.0.0 in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mne==1.0.0) (3.7.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mne==1.0.0) (4.67.1)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.11/dist-packages (from mne==1.0.0) (1.8.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from mne==1.0.0) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mne==1.0.0) (25.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from mne==1.0.0) (3.1.6)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (2.4.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne==1.0.0) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne==1.0.0) (2.32.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->mne==1.0.0) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mne==1.0.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mne==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mne==1.0.0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mne==1.0.0) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mne==1.0.0) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mne==1.0.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mne==1.0.0) (2.9.0.post0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy==1.26.4) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy==1.26.4) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy==1.26.4) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy==1.26.4) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy==1.26.4) (2024.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mne==1.0.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne==1.0.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne==1.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne==1.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne==1.0.0) (2025.8.3)

# %% [markdown]
# # **Import Libraries**

# %%
import os
import mne
import time
import math
import pickle
import random
import datetime
import scipy.io
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim
from einops import rearrange
from torchinfo import summary
import matplotlib.pyplot as plt
from sklearn.utils import class_weight
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from einops.layers.torch import Rearrange, Reduce
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import LeaveOneGroupOut, train_test_split

# %%
###############################################################################
# 1) Set seeds for reproducibility
###############################################################################
import random
import numpy as np
import torch
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import LeaveOneGroupOut, train_test_split
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from einops.layers.torch import Rearrange
import mne

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)

###############################################################################
# 2) Load & preprocess data from the pickle file
###############################################################################
def pad_and_resize_eeg(eeg_2d, target_h=3, target_w=321):
    """
    Zero-pad or resize EEG data to ensure consistent dimensions
    
    Args:
        eeg_2d (np.ndarray): EEG data of shape (channels, time_samples)
        target_h (int): Target number of EEG channels
        target_w (int): Target number of time samples
    
    Returns:
        np.ndarray: Zero-padded EEG data of shape (target_h, target_w)
    """
    out = np.zeros((target_h, target_w), dtype=eeg_2d.dtype)
    h, w = eeg_2d.shape
    used_h = min(h, target_h)
    used_w = min(w, target_w)
    out[:used_h, :used_w] = eeg_2d[:used_h, :used_w]
    return out

def load_and_preprocess_data(pickle_path, target_h=3, target_w=321, l_freq=7, h_freq=30):
    """
    Loads and preprocesses EEG data from a pickle file

    Args:
        pickle_path (str): Path to the pickle file
        target_h (int): Target number of EEG channels
        target_w (int): Target number of time samples
        l_freq (float): Low cutoff frequency for band-pass filter
        h_freq (float): High cutoff frequency for band-pass filter

    Returns:
        all_X (np.ndarray): Preprocessed EEG data of shape (trials, 1, channels, time_samples)
        all_y (np.ndarray): Labels of shape (trials,)
        all_subjects (np.ndarray): Subject indices for each trial
    """
    with open(pickle_path, 'rb') as f:
        raw_data = pickle.load(f)  # List of MNE Epochs, one per subject

    all_X = []
    all_y = []
    all_subjects = []

    for subj_idx, epochs in enumerate(raw_data):
        # Apply band-pass filter
        epochs = epochs.copy().filter(l_freq=l_freq, h_freq=h_freq)
        X = epochs.get_data()  # (trials, channels, time_samples)
        y = epochs.events[:, 2]  # (trials,)

        # Mapping: Left Hand = 0, Right Hand = 1
        y = np.where(y == 1, 0, 1)

        # Resize each trial
        padded = [pad_and_resize_eeg(trial, target_h, target_w) for trial in X]
        padded_array = np.array(padded)  # (trials, channels, time_samples)

        # Expand dimensions to match (B, 1, C, T)
        padded_array = np.expand_dims(padded_array, axis=1)  # (trials, 1, channels, time_samples)

        all_X.append(padded_array)
        all_y.append(y)
        all_subjects += [subj_idx] * len(y)

    all_X = np.concatenate(all_X, axis=0)  # (total_trials, 1, channels, time_samples)
    all_y = np.concatenate(all_y, axis=0)  # (total_trials,)
    all_subjects = np.array(all_subjects)   # (total_trials,)

    # Standardize
    scaler = StandardScaler()
    # Reshape to (trials, channels * time_samples) for scaling
    all_X_reshaped = all_X.reshape(all_X.shape[0], -1)
    all_X_scaled = scaler.fit_transform(all_X_reshaped)
    all_X = all_X_scaled.reshape(all_X.shape[0], 1, target_h, target_w).astype(np.float32)

    return all_X, all_y, all_subjects

###############################################################################
# 3) Dataset without augmentation
###############################################################################
class MultiSubjectBCIDataset(Dataset):
    def __init__(self, X, y, augment=False):
        """
        Args:
            X (np.ndarray): EEG data of shape (trials, 1, channels, time_samples)
            y (np.ndarray): Labels of shape (trials,)
            augment (bool): Whether to apply data augmentation (kept for compatibility, but ignored)
        """
        self.X = X
        self.y = y
        # self.augment = augment
        # self.max_shift = 10     # shift range
        # self.noise_amp = 0.01   # noise amplitude
        # self.dropout_rate = 0.05

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x_np = self.X[idx]  # shape: (1, channels, time_samples)
        y = self.y[idx]

        # Convert to torch without any augmentation
        x_t = torch.from_numpy(x_np).float()  # (1, channels, time_samples)
        return x_t, torch.tensor(y).long()

###############################################################################
# 4) Window-partitioning & shift for Swin-1D
###############################################################################
def pad_sequence_1d(x, window_size):
    """
    x shape: (B, L, C)
    Zero-pad or resize length to multiple of window_size
    """
    B, L, C = x.shape
    remainder = L % window_size
    if remainder == 0:
        return x, L, 0
    pad_len = window_size - remainder
    pad_vec = torch.zeros(B, pad_len, C, dtype=x.dtype, device=x.device)
    x_padded = torch.cat([x, pad_vec], dim=1)
    return x_padded, L, pad_len

def window_partition_1d(x, window_size):
    """
    x shape: (B, L, C) => (B*nW, window_size, C)
    """
    B, L, C = x.shape
    x_padded, orig_L, pad_len = pad_sequence_1d(x, window_size)
    Bp, Lp, Cp = x_padded.shape
    num_windows = Lp // window_size
    x_padded = x_padded.view(Bp, num_windows, window_size, Cp)
    x_windows = x_padded.reshape(Bp * num_windows, window_size, Cp)
    return x_windows, (orig_L, pad_len, num_windows)

def window_reverse_1d(x_windows, window_size, pad_info):
    """
    Reconstruct from (B*nW, window_size, C) => (B, L, C)
    """
    orig_L, pad_len, num_windows = pad_info
    BnW, WS, C = x_windows.shape
    B = BnW // num_windows
    x_reshaped = x_windows.view(B, num_windows, WS, C)
    x_merged = x_reshaped.reshape(B, num_windows * WS, C)
    if pad_len > 0:
        x_merged = x_merged[:, :orig_L, :]
    return x_merged

def cyclic_shift_1d(x, shift_size):
    """
    Negative roll along dimension=1
    """
    return torch.roll(x, shifts=-shift_size, dims=1)

def cyclic_shift_back_1d(x, shift_size):
    return torch.roll(x, shifts=shift_size, dims=1)

###############################################################################
# 5) Custom QKV Attention & MLP
###############################################################################
class Attention(nn.Module):
    def __init__(self, dim, num_heads, attn_dropout=0.1):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=False)
        self.attn_drop = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(attn_dropout)

    def forward(self, x):
        B, L, C = x.shape
        qkv = self.qkv(x).reshape(B, L, 3, self.num_heads, C // self.num_heads)
        qkv = qkv.permute(2, 0, 3, 1, 4)  # (3, B, num_heads, L, head_dim)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale  # (B, num_heads, L, L)
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        out = (attn @ v).transpose(1, 2).reshape(B, L, C)  # (B, L, C)
        out = self.proj(out)
        out = self.proj_drop(out)
        return out

class MLP(nn.Module):
    def __init__(self, dim, hidden_dim, dropout=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.net(x)

###############################################################################
# 6) Swin1DBlock & Swin1DTransformer
###############################################################################
class Swin1DBlock(nn.Module):
    def __init__(
        self,
        dim,
        num_heads,
        window_size=4,
        shift_size=2,
        mlp_hidden=128,
        attn_dropout=0.1
    ):
        super().__init__()
        self.window_size = window_size
        self.shift_size = shift_size

        # LayerNorm & Attention
        self.ln1 = nn.LayerNorm(dim)
        self.attn = Attention(dim=dim, num_heads=num_heads, attn_dropout=attn_dropout)

        # LayerNorm & MLP
        self.ln2 = nn.LayerNorm(dim)
        self.mlp = MLP(dim=dim, hidden_dim=mlp_hidden, dropout=attn_dropout)

    def forward(self, x):
        # x: (B, L, dim)
        if self.shift_size > 0:
            x = cyclic_shift_1d(x, self.shift_size)

        x_windows, pad_info = window_partition_1d(x, self.window_size)

        # Attention + residual
        shortcut = x_windows
        x_windows = self.ln1(x_windows)
        x_windows = self.attn(x_windows)
        x_windows = shortcut + x_windows

        # MLP + residual
        shortcut = x_windows
        x_windows = self.ln2(x_windows)
        x_windows = self.mlp(x_windows)
        x_windows = shortcut + x_windows

        x_merged = window_reverse_1d(x_windows, self.window_size, pad_info)
        if self.shift_size > 0:
            x_merged = cyclic_shift_back_1d(x_merged, self.shift_size)
        return x_merged

class Swin1DTransformer(nn.Module):
    def __init__(
        self,
        dim=64,           # Embedding dimension
        num_layers=3,     # Number of Swin1DBlock layers
        num_heads=4,      # Number of attention heads
        mlp_hidden=128,   # Hidden dimension in MLP
        window_size=4,    # Window size for attention
        attn_dropout=0.1, # Dropout rate for attention
        fc_dropout=0.3    # Dropout rate before final FC
    ):
        super().__init__()
        blocks = []
        for i in range(num_layers):
            shift = window_size // 2 if (i % 2 == 1) else 0
            block = Swin1DBlock(
                dim=dim,
                num_heads=num_heads,
                window_size=window_size,
                shift_size=shift,
                mlp_hidden=mlp_hidden,
                attn_dropout=attn_dropout
            )
            blocks.append(block)

        self.blocks = nn.ModuleList(blocks)
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        # x: (B, L, dim)
        for blk in self.blocks:
            x = blk(x)
        x = self.norm(x)
        # average pooling over the L dimension
        x = x.mean(dim=1)  # (B, dim)
        return x  # Feature Vector: (B, dim)

###############################################################################
# 7) Positional Embeddings: learnable, sine, or none
###############################################################################
def create_positional_embedding(mode, seq_len, dim):
    """
    Creates positional embeddings

    Args:
        mode (str): 'learnable', 'sine', or 'none'
        seq_len (int): Sequence length
        dim (int): Embedding dimension

    Returns:
        nn.Parameter or None: Positional embedding tensor
    """
    if mode == 'none':
        return None
    elif mode == 'learnable':
        pe = nn.Parameter(torch.zeros(1, seq_len, dim))
        nn.init.trunc_normal_(pe, std=0.02)
        return pe
    elif mode == 'sine':
        # Classic sinusoidal
        pe_np = np.zeros((seq_len, dim))
        for pos in range(seq_len):
            for i in range(0, dim, 2):
                theta = pos / (10000 ** ((2 * i) / dim))
                pe_np[pos, i]   = np.sin(theta)
                if i+1 < dim:
                    pe_np[pos, i+1] = np.cos(theta)
        pe = torch.from_numpy(pe_np).float().unsqueeze(0)  # shape (1, seq_len, dim)
        return nn.Parameter(pe, requires_grad=False)
    else:
        raise ValueError(f"Unsupported positional embedding mode: {mode}")

###############################################################################
# 8) Patch Embedding
###############################################################################
class PatchEmbedding(nn.Module):
    def __init__(self, emb_size=40):
        super().__init__()

        self.shallownet = nn.Sequential(
            nn.Conv2d(1, 40, kernel_size=(1, 25), stride=(1, 1)),  # Temporal convolution
            nn.Conv2d(40, 40, kernel_size=(3, 1), stride=(1, 1)),  # Spatial convolution across electrodes
            nn.BatchNorm2d(40),
            nn.ELU(),
            nn.AvgPool2d(kernel_size=(1, 75), stride=(1, 15)),  # Downsample temporal dimension
            nn.Dropout(p=0.5),
            nn.Conv2d(40, emb_size, kernel_size=(1,1), stride=(1,1))  # Projection to emb_size
        )
        self.rearrange = Rearrange('b e (h) (w) -> b (h w) e')  # Reshape to (B, seq_len, emb_size)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.shallownet(x)           # [B, emb_size, 1, w]
        x = self.rearrange(x)            # [B, seq_len, emb_size]
        return x

###############################################################################
# 9) Classification Head
###############################################################################
class ClassificationHead(nn.Module):
    def __init__(self, input_dim=64, num_classes=2):
        super(ClassificationHead, self).__init__()
        self.dropout = nn.Dropout(p=0.3)
        self.linear = nn.Linear(input_dim, num_classes)

    def forward(self, x):
        x = self.dropout(x)            # [B, dim]
        logits = self.linear(x)        # [B, num_classes]
        return logits


###############################################################################
# 10) CCST
###############################################################################
class CCST(nn.Module):
    def __init__(
        self,
        emb_size=40,
        swin_embedding_dim=64,
        num_swin_layers=3,
        num_heads=4,
        mlp_size=128,
        fc_dropout=0.3,
        pos_emb_mode='learnable',
        num_classes=2
    ):
        super().__init__()
        self.patch_embedding = PatchEmbedding(emb_size=emb_size)  # [B, seq_len, emb_size]
        self.embedding_projection = nn.Linear(emb_size, swin_embedding_dim)  # [B, seq_len, swin_embedding_dim]
        self.pos_encoding = create_positional_embedding(pos_emb_mode, seq_len=15, dim=swin_embedding_dim)
        self.transformer = Swin1DTransformer(
            dim=swin_embedding_dim,
            num_layers=num_swin_layers,
            num_heads=num_heads,
            mlp_hidden=mlp_size,
            window_size=4,
            attn_dropout=0.1
        )
        self.classification_head = ClassificationHead(input_dim=swin_embedding_dim, num_classes=num_classes)  # [B, num_classes]

    def forward(self, x):
        """
        Args:
            x (torch.Tensor): Input tensor of shape (B, 1, 3, 321)
        
        Returns:
            torch.Tensor: Logits of shape (B, num_classes)
        """
        x = self.patch_embedding(x)         # [B, seq_len, emb_size]
        x = self.embedding_projection(x)    # [B, seq_len, swin_embedding_dim]
        if self.pos_encoding is not None:
            x = x + self.pos_encoding[:, :x.size(1), :]
        features = self.transformer(x)      # [B, swin_embedding_dim]
        logits = self.classification_head(features)  # [B, num_classes]
        return logits

###############################################################################
# 11) Training and Evaluation
###############################################################################
class HybridExP():
    def __init__(self, nsub, pickle_path='/kaggle/input/2b.pickle', device='cuda:0'):
        super(HybridExP, self).__init__()
        self.batch_size = 72
        self.n_epochs = 100
        self.patience = 10
        self.c_dim = 2  # Number of classes (Left Hand, Right Hand)
        self.lr = 3e-4
        self.betas = (0.9, 0.999)
        self.nSub = nsub
        self.pickle_path = pickle_path
        self.device = torch.device(device if torch.cuda.is_available() else "cpu")

        self.criterion_cls = nn.CrossEntropyLoss().to(self.device)

        self.model = CCST(num_classes=self.c_dim).to(self.device)
        self.model = nn.DataParallel(self.model)
        self.model = self.model.to(self.device)

    # Data augmentation method (kept for compatibility, does nothing)
    def interaug(self, timg, label):
        """
        Placeholder for additional data augmentation (returns unchanged data)
        """
        return timg, label

    # Load data
    def get_source_data(self):
        # Load and preprocess data
        all_X, all_y, all_subjects = load_and_preprocess_data(
            pickle_path=self.pickle_path,
            target_h=3,
            target_w=321,
            l_freq=7,
            h_freq=30
        )

        return all_X, all_y, all_subjects

    # Training method for one fold
    def train_fold(self, train_indices, val_indices, test_indices, train_labels, test_labels):
        # Split data into training and validation
        X_train = self.X[train_indices]
        y_train = self.y[train_indices]
        X_val = self.X[val_indices]
        y_val = self.y[val_indices]
        X_test = self.X[test_indices]
        y_test = self.y[test_indices]

        # Create datasets without augmentation
        train_ds = MultiSubjectBCIDataset(X_train, y_train, augment=False)
        val_ds = MultiSubjectBCIDataset(X_val, y_val, augment=False)
        test_ds = MultiSubjectBCIDataset(X_test, y_test, augment=False)

        # Create dataloaders
        train_loader = DataLoader(train_ds, batch_size=self.batch_size, shuffle=True)
        val_loader = DataLoader(val_ds, batch_size=self.batch_size, shuffle=False)
        test_loader = DataLoader(test_ds, batch_size=self.batch_size, shuffle=False)

        # Define optimizer and scheduler
        optimizer = optim.Adam(self.model.parameters(), lr=self.lr, betas=self.betas)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                         factor=0.5, patience=5, verbose=True)

        best_val_acc = 0.0
        patience_counter = 0
        best_model_state = None

        for epoch in range(self.n_epochs):
            # Training Phase
            self.model.train()
            running_loss = 0.0
            correct = 0
            total = 0

            for img, label in train_loader:
                img = img.to(self.device)  # (B, 1, 3, 321)
                label = label.to(self.device)  # (B,)

                optimizer.zero_grad()
                outputs = self.model(img)  # (B, num_classes)
                loss = self.criterion_cls(outputs, label)
                loss.backward()
                optimizer.step()

                running_loss += loss.item() * img.size(0)
                _, preds = torch.max(outputs, 1)
                correct += (preds == label).sum().item()
                total += label.size(0)

            train_loss = running_loss / total
            train_acc = correct / total

            # Validation Phase
            self.model.eval()
            val_loss = 0.0
            val_correct = 0
            val_total = 0

            with torch.no_grad():
                for img, label in val_loader:
                    img = img.to(self.device)
                    label = label.to(self.device)

                    outputs = self.model(img)
                    loss = self.criterion_cls(outputs, label)

                    val_loss += loss.item() * img.size(0)
                    _, preds = torch.max(outputs, 1)
                    val_correct += (preds == label).sum().item()
                    val_total += label.size(0)

            val_loss /= val_total
            val_acc = val_correct / val_total

            # Step scheduler
            scheduler.step(val_loss)

            print(f'Epoch {epoch+1}/{self.n_epochs} | '
                  f'Train Loss: {train_loss:.4f} | Train Acc: {train_acc*100:.2f}% | '
                  f'Val Loss: {val_loss:.4f} | Val Acc: {val_acc*100:.2f}%')

            # Early Stopping
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_model_state = self.model.state_dict()
                patience_counter = 0
            else:
                patience_counter += 1
                # if patience_counter >= self.patience:
                #     print(f"Early stopping triggered at epoch {epoch+1}")
                #     break

        # Load best model
        if best_model_state is not None:
            self.model.load_state_dict(best_model_state)

        # Testing Phase
        self.model.eval()
        test_loss = 0.0
        test_correct = 0
        test_total = 0
        all_preds = []
        all_labels = []

        with torch.no_grad():
            for img, label in test_loader:
                img = img.to(self.device)
                label = label.to(self.device)

                outputs = self.model(img)
                loss = self.criterion_cls(outputs, label)

                test_loss += loss.item() * img.size(0)
                _, preds = torch.max(outputs, 1)
                test_correct += (preds == label).sum().item()
                test_total += label.size(0)

                all_preds.append(preds.cpu().numpy())
                all_labels.append(label.cpu().numpy())

        test_loss /= test_total
        test_acc = test_correct / test_total

        all_preds = np.concatenate(all_preds)
        all_labels = np.concatenate(all_labels)

        print(f'Test Loss: {test_loss:.4f} | Test Acc: {test_acc*100:.2f}%')

        return test_acc, all_labels, all_preds

    # Training method with LOSO cross-validation
    def train_loso(self):
        # Load data
        self.X, self.y, self.subjects = self.get_source_data()

        logo = LeaveOneGroupOut()
        device = self.device

        test_accuracies = []
        subject_ids = []
        fold_count = 0

        print("\n####################")
        print("Traininig Started")
        print("####################")
        
        for train_idx, test_idx in logo.split(self.X, self.y, groups=self.subjects):
            fold_count += 1
            heldout_subj = self.subjects[test_idx[0]]
            training_subjects = np.unique(self.subjects[train_idx])
            # Convert to 1-based indexing for display
            training_subjects_1based = [s + 1 for s in training_subjects]
            test_subj_1based = heldout_subj + 1
            print(f"\n===== Fold {fold_count}")
            print(f"===== Seed : {42+fold_count}")
            print(f"===== Training Subject : {', '.join(map(str, training_subjects_1based))}")
            print(f"===== Test Subject : {test_subj_1based}\n")

            # Re-seed per fold for reproducibility
            set_seed(42 + fold_count)

            X_train_full, X_test = self.X[train_idx], self.X[test_idx]
            y_train_full, y_test = self.y[train_idx], self.y[test_idx]

            # Further split training data into training and validation (e.g., 90-10)
            X_train, X_val, y_train, y_val = train_test_split(
                X_train_full, y_train_full, test_size=0.1,
                stratify=y_train_full, random_state=42 + fold_count
            )

            # Create datasets without augmentation
            train_ds = MultiSubjectBCIDataset(X_train, y_train, augment=False)
            val_ds = MultiSubjectBCIDataset(X_val, y_val, augment=False)
            test_ds = MultiSubjectBCIDataset(X_test, y_test, augment=False)

            # Create dataloaders
            train_loader = DataLoader(train_ds, batch_size=self.batch_size, shuffle=True)
            val_loader = DataLoader(val_ds, batch_size=self.batch_size, shuffle=False)
            test_loader = DataLoader(test_ds, batch_size=self.batch_size, shuffle=False)

            # Define optimizer and scheduler
            optimizer = optim.Adam(self.model.parameters(), lr=self.lr, betas=self.betas)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                             factor=0.5, patience=5, verbose=True)

            best_val_acc = 0.0
            patience_counter = 0
            best_model_state = None

            for epoch in range(self.n_epochs):
                # Training Phase
                self.model.train()
                running_loss = 0.0
                correct = 0
                total = 0

                for img, label in train_loader:
                    img = img.to(self.device)  # (B, 1, 3, 321)
                    label = label.to(self.device)  # (B,)

                    optimizer.zero_grad()
                    outputs = self.model(img)  # (B, num_classes)
                    loss = self.criterion_cls(outputs, label)
                    loss.backward()
                    optimizer.step()

                    running_loss += loss.item() * img.size(0)
                    _, preds = torch.max(outputs, 1)
                    correct += (preds == label).sum().item()
                    total += label.size(0)

                train_loss = running_loss / total
                train_acc = correct / total

                # Validation Phase
                self.model.eval()
                val_loss = 0.0
                val_correct = 0
                val_total = 0

                with torch.no_grad():
                    for img, label in val_loader:
                        img = img.to(self.device)
                        label = label.to(self.device)

                        outputs = self.model(img)
                        loss = self.criterion_cls(outputs, label)

                        val_loss += loss.item() * img.size(0)
                        _, preds = torch.max(outputs, 1)
                        val_correct += (preds == label).sum().item()
                        val_total += label.size(0)

                val_loss /= val_total
                val_acc = val_correct / val_total

                # Step scheduler
                scheduler.step(val_loss)

                print(f'Epoch {epoch+1}/{self.n_epochs} | '
                      f'Training Loss : {train_loss:.4f} | Training Accuracy : {train_acc*100:.2f} % | '
                      f'Validation Loss : {val_loss:.4f} | Validation Accuracy : {val_acc*100:.2f} %')

                # Early Stopping
                if val_acc > best_val_acc:
                    best_val_acc = val_acc
                    best_model_state = self.model.state_dict()
                    patience_counter = 0
                else:
                    patience_counter += 1
                    # if patience_counter >= self.patience:
                    #     print(f"\n=== Early Stopping Triggered at Epoch {epoch+1}\n")
                    #     break

            # Load best model
            if best_model_state is not None:
                self.model.load_state_dict(best_model_state)

            # Testing Phase
            self.model.eval()
            test_loss = 0.0
            test_correct = 0
            test_total = 0
            all_preds = []
            all_labels = []

            with torch.no_grad():
                for img, label in test_loader:
                    img = img.to(self.device)
                    label = label.to(self.device)

                    outputs = self.model(img)
                    loss = self.criterion_cls(outputs, label)

                    test_loss += loss.item() * img.size(0)
                    _, preds = torch.max(outputs, 1)
                    test_correct += (preds == label).sum().item()
                    test_total += label.size(0)

                    all_preds.append(preds.cpu().numpy())
                    all_labels.append(label.cpu().numpy())

            test_loss /= test_total
            test_acc = test_correct / test_total

            all_preds = np.concatenate(all_preds)
            all_labels = np.concatenate(all_labels)

            print(f'Test Subject : {test_subj_1based} | Test Loss : {test_loss:.4f} | Test Accuracy : {test_acc*100:.2f} %')
            print("\n################################")

            test_accuracies.append(test_acc)
            subject_ids.append(heldout_subj)

        # Summary of LOSO
        avg_test_acc = np.mean(test_accuracies) * 100
        
        print("\n================")
        print("LOSO Summary")
        print("================")
        for i, sid in enumerate(subject_ids):
            print(f"Subject {sid} -> Test Accuracy : {test_accuracies[i]*100:.2f} %")
        print("\n-----------------------------")
        print(f"Average Test Accuracy : {avg_test_acc:.2f} %")
        print("-----------------------------")

###############################################################################
# 12) Main Execution
###############################################################################
def main():
    best = 0
    aver = 0

    # Path to the pickle file
    pickle_path = '/kaggle/input/2b.pickle'

    # Initialize and train the model
    exp = HybridExP(nsub=1, pickle_path=pickle_path, device='cuda:0')  # 'nsub' will be managed by LOSO
    exp.train_loso()

if __name__ == "__main__":
    main()
# Out:
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 133 samples (1.663 sec)
#
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 133 samples (1.663 sec)
#
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 133 samples (1.663 sec)
#
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 133 samples (1.663 sec)
#
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 133 samples (1.663 sec)
#
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 133 samples (1.663 sec)
#
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 133 samples (1.663 sec)
#
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 133 samples (1.663 sec)
#
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 133 samples (1.663 sec)
#
#
# ####################
# Traininig Started
# ####################
#
# ===== Fold 1
# ===== Seed : 43
# ===== Training Subject : 2, 3, 4, 5, 6, 7, 8, 9
# ===== Test Subject : 1
#
# Epoch 1/100 | Training Loss : 0.6549 | Training Accuracy : 59.96 % | Validation Loss : 0.5702 | Validation Accuracy : 68.10 %
# Epoch 2/100 | Training Loss : 0.5739 | Training Accuracy : 68.89 % | Validation Loss : 0.5262 | Validation Accuracy : 70.52 %
# Epoch 3/100 | Training Loss : 0.5558 | Training Accuracy : 69.90 % | Validation Loss : 0.5131 | Validation Accuracy : 70.69 %
# Epoch 4/100 | Training Loss : 0.5184 | Training Accuracy : 72.74 % | Validation Loss : 0.5019 | Validation Accuracy : 73.10 %
# Epoch 5/100 | Training Loss : 0.5201 | Training Accuracy : 72.93 % | Validation Loss : 0.5077 | Validation Accuracy : 70.86 %
# Epoch 6/100 | Training Loss : 0.5060 | Training Accuracy : 72.97 % | Validation Loss : 0.4916 | Validation Accuracy : 72.59 %
# Epoch 7/100 | Training Loss : 0.5068 | Training Accuracy : 73.22 % | Validation Loss : 0.4903 | Validation Accuracy : 72.76 %
# Epoch 8/100 | Training Loss : 0.4997 | Training Accuracy : 74.39 % | Validation Loss : 0.4909 | Validation Accuracy : 73.97 %
# Epoch 9/100 | Training Loss : 0.4915 | Training Accuracy : 74.56 % | Validation Loss : 0.4848 | Validation Accuracy : 72.93 %
# Epoch 10/100 | Training Loss : 0.4884 | Training Accuracy : 73.77 % | Validation Loss : 0.4814 | Validation Accuracy : 73.28 %
# Epoch 11/100 | Training Loss : 0.4819 | Training Accuracy : 75.00 % | Validation Loss : 0.4780 | Validation Accuracy : 73.97 %
# Epoch 12/100 | Training Loss : 0.4809 | Training Accuracy : 74.81 % | Validation Loss : 0.4899 | Validation Accuracy : 72.07 %
# Epoch 13/100 | Training Loss : 0.4871 | Training Accuracy : 74.67 % | Validation Loss : 0.4756 | Validation Accuracy : 74.31 %
# Epoch 14/100 | Training Loss : 0.4864 | Training Accuracy : 74.94 % | Validation Loss : 0.4816 | Validation Accuracy : 75.69 %
# Epoch 15/100 | Training Loss : 0.4900 | Training Accuracy : 74.08 % | Validation Loss : 0.4772 | Validation Accuracy : 74.66 %
# Epoch 16/100 | Training Loss : 0.4744 | Training Accuracy : 75.10 % | Validation Loss : 0.4770 | Validation Accuracy : 73.97 %
# Epoch 17/100 | Training Loss : 0.4660 | Training Accuracy : 76.49 % | Validation Loss : 0.4709 | Validation Accuracy : 72.93 %
# Epoch 18/100 | Training Loss : 0.4747 | Training Accuracy : 75.29 % | Validation Loss : 0.4787 | Validation Accuracy : 73.79 %
# Epoch 19/100 | Training Loss : 0.4733 | Training Accuracy : 75.82 % | Validation Loss : 0.4734 | Validation Accuracy : 74.66 %
# Epoch 20/100 | Training Loss : 0.4709 | Training Accuracy : 75.23 % | Validation Loss : 0.4785 | Validation Accuracy : 73.79 %
# Epoch 21/100 | Training Loss : 0.4639 | Training Accuracy : 75.61 % | Validation Loss : 0.4857 | Validation Accuracy : 72.76 %
# Epoch 22/100 | Training Loss : 0.4736 | Training Accuracy : 75.52 % | Validation Loss : 0.4794 | Validation Accuracy : 75.00 %
# Epoch 23/100 | Training Loss : 0.4736 | Training Accuracy : 75.02 % | Validation Loss : 0.4783 | Validation Accuracy : 74.31 %
# Epoch 24/100 | Training Loss : 0.4572 | Training Accuracy : 75.56 % | Validation Loss : 0.4724 | Validation Accuracy : 73.62 %
# Epoch 25/100 | Training Loss : 0.4592 | Training Accuracy : 76.23 % | Validation Loss : 0.4719 | Validation Accuracy : 74.31 %
# Epoch 26/100 | Training Loss : 0.4561 | Training Accuracy : 76.36 % | Validation Loss : 0.4640 | Validation Accuracy : 74.31 %
# Epoch 27/100 | Training Loss : 0.4559 | Training Accuracy : 75.98 % | Validation Loss : 0.4683 | Validation Accuracy : 74.14 %
# Epoch 28/100 | Training Loss : 0.4581 | Training Accuracy : 75.31 % | Validation Loss : 0.4699 | Validation Accuracy : 72.93 %
# Epoch 29/100 | Training Loss : 0.4505 | Training Accuracy : 76.34 % | Validation Loss : 0.4675 | Validation Accuracy : 75.00 %
# Epoch 30/100 | Training Loss : 0.4603 | Training Accuracy : 76.26 % | Validation Loss : 0.4637 | Validation Accuracy : 75.17 %
# Epoch 31/100 | Training Loss : 0.4596 | Training Accuracy : 75.46 % | Validation Loss : 0.4664 | Validation Accuracy : 76.38 %
# Epoch 32/100 | Training Loss : 0.4533 | Training Accuracy : 77.05 % | Validation Loss : 0.4719 | Validation Accuracy : 73.62 %
# Epoch 33/100 | Training Loss : 0.4458 | Training Accuracy : 76.32 % | Validation Loss : 0.4657 | Validation Accuracy : 75.52 %
# Epoch 34/100 | Training Loss : 0.4524 | Training Accuracy : 76.07 % | Validation Loss : 0.4660 | Validation Accuracy : 74.66 %
# Epoch 35/100 | Training Loss : 0.4525 | Training Accuracy : 76.38 % | Validation Loss : 0.4791 | Validation Accuracy : 75.34 %
# Epoch 36/100 | Training Loss : 0.4540 | Training Accuracy : 76.74 % | Validation Loss : 0.4755 | Validation Accuracy : 73.97 %
# Epoch 37/100 | Training Loss : 0.4395 | Training Accuracy : 76.82 % | Validation Loss : 0.4699 | Validation Accuracy : 74.31 %
# Epoch 38/100 | Training Loss : 0.4443 | Training Accuracy : 76.46 % | Validation Loss : 0.4649 | Validation Accuracy : 76.38 %
# Epoch 39/100 | Training Loss : 0.4538 | Training Accuracy : 76.30 % | Validation Loss : 0.4684 | Validation Accuracy : 73.79 %
# Epoch 40/100 | Training Loss : 0.4486 | Training Accuracy : 76.55 % | Validation Loss : 0.4670 | Validation Accuracy : 74.48 %
# Epoch 41/100 | Training Loss : 0.4479 | Training Accuracy : 76.07 % | Validation Loss : 0.4662 | Validation Accuracy : 75.52 %
# Epoch 42/100 | Training Loss : 0.4428 | Training Accuracy : 76.67 % | Validation Loss : 0.4692 | Validation Accuracy : 74.66 %
# Epoch 43/100 | Training Loss : 0.4378 | Training Accuracy : 77.66 % | Validation Loss : 0.4743 | Validation Accuracy : 76.55 %
# Epoch 44/100 | Training Loss : 0.4363 | Training Accuracy : 77.05 % | Validation Loss : 0.4707 | Validation Accuracy : 75.34 %
# Epoch 45/100 | Training Loss : 0.4409 | Training Accuracy : 76.88 % | Validation Loss : 0.4724 | Validation Accuracy : 74.66 %
# Epoch 46/100 | Training Loss : 0.4419 | Training Accuracy : 77.45 % | Validation Loss : 0.4695 | Validation Accuracy : 74.48 %
# Epoch 47/100 | Training Loss : 0.4387 | Training Accuracy : 77.36 % | Validation Loss : 0.4695 | Validation Accuracy : 75.86 %
# Epoch 48/100 | Training Loss : 0.4385 | Training Accuracy : 77.16 % | Validation Loss : 0.4665 | Validation Accuracy : 74.66 %
# Epoch 49/100 | Training Loss : 0.4385 | Training Accuracy : 77.11 % | Validation Loss : 0.4671 | Validation Accuracy : 75.52 %
# Epoch 50/100 | Training Loss : 0.4530 | Training Accuracy : 76.70 % | Validation Loss : 0.4656 | Validation Accuracy : 74.48 %
# Epoch 51/100 | Training Loss : 0.4457 | Training Accuracy : 77.20 % | Validation Loss : 0.4684 | Validation Accuracy : 75.86 %
# Epoch 52/100 | Training Loss : 0.4416 | Training Accuracy : 76.72 % | Validation Loss : 0.4656 | Validation Accuracy : 75.52 %
# Epoch 53/100 | Training Loss : 0.4382 | Training Accuracy : 77.13 % | Validation Loss : 0.4675 | Validation Accuracy : 75.34 %
# Epoch 54/100 | Training Loss : 0.4389 | Training Accuracy : 77.62 % | Validation Loss : 0.4680 | Validation Accuracy : 75.34 %
# Epoch 55/100 | Training Loss : 0.4385 | Training Accuracy : 77.07 % | Validation Loss : 0.4680 | Validation Accuracy : 75.52 %
# Epoch 56/100 | Training Loss : 0.4327 | Training Accuracy : 76.99 % | Validation Loss : 0.4681 | Validation Accuracy : 74.66 %
# Epoch 57/100 | Training Loss : 0.4353 | Training Accuracy : 77.41 % | Validation Loss : 0.4659 | Validation Accuracy : 74.31 %
# Epoch 58/100 | Training Loss : 0.4333 | Training Accuracy : 77.30 % | Validation Loss : 0.4695 | Validation Accuracy : 75.52 %
# Epoch 59/100 | Training Loss : 0.4361 | Training Accuracy : 77.43 % | Validation Loss : 0.4715 | Validation Accuracy : 76.03 %
# Epoch 60/100 | Training Loss : 0.4344 | Training Accuracy : 77.03 % | Validation Loss : 0.4667 | Validation Accuracy : 75.86 %
# Epoch 61/100 | Training Loss : 0.4341 | Training Accuracy : 77.59 % | Validation Loss : 0.4695 | Validation Accuracy : 75.52 %
# Epoch 62/100 | Training Loss : 0.4427 | Training Accuracy : 76.88 % | Validation Loss : 0.4679 | Validation Accuracy : 75.52 %
# Epoch 63/100 | Training Loss : 0.4418 | Training Accuracy : 77.11 % | Validation Loss : 0.4699 | Validation Accuracy : 74.83 %
# Epoch 64/100 | Training Loss : 0.4420 | Training Accuracy : 77.07 % | Validation Loss : 0.4695 | Validation Accuracy : 76.38 %
# Epoch 65/100 | Training Loss : 0.4360 | Training Accuracy : 76.92 % | Validation Loss : 0.4681 | Validation Accuracy : 75.52 %
# Epoch 66/100 | Training Loss : 0.4341 | Training Accuracy : 77.18 % | Validation Loss : 0.4693 | Validation Accuracy : 75.34 %
# Epoch 67/100 | Training Loss : 0.4351 | Training Accuracy : 77.61 % | Validation Loss : 0.4687 | Validation Accuracy : 74.83 %
# Epoch 68/100 | Training Loss : 0.4364 | Training Accuracy : 77.45 % | Validation Loss : 0.4674 | Validation Accuracy : 75.17 %
# Epoch 69/100 | Training Loss : 0.4384 | Training Accuracy : 77.18 % | Validation Loss : 0.4681 | Validation Accuracy : 74.83 %
# Epoch 70/100 | Training Loss : 0.4388 | Training Accuracy : 77.20 % | Validation Loss : 0.4691 | Validation Accuracy : 74.66 %
# Epoch 71/100 | Training Loss : 0.4350 | Training Accuracy : 77.55 % | Validation Loss : 0.4700 | Validation Accuracy : 75.17 %
# Epoch 72/100 | Training Loss : 0.4397 | Training Accuracy : 77.41 % | Validation Loss : 0.4680 | Validation Accuracy : 74.66 %
# Epoch 73/100 | Training Loss : 0.4398 | Training Accuracy : 77.49 % | Validation Loss : 0.4675 | Validation Accuracy : 74.48 %
# Epoch 74/100 | Training Loss : 0.4421 | Training Accuracy : 77.34 % | Validation Loss : 0.4700 | Validation Accuracy : 74.66 %
# Epoch 75/100 | Training Loss : 0.4309 | Training Accuracy : 77.76 % | Validation Loss : 0.4701 | Validation Accuracy : 74.48 %
# Epoch 76/100 | Training Loss : 0.4339 | Training Accuracy : 77.66 % | Validation Loss : 0.4696 | Validation Accuracy : 74.83 %
# Epoch 77/100 | Training Loss : 0.4298 | Training Accuracy : 77.57 % | Validation Loss : 0.4688 | Validation Accuracy : 75.69 %
# Epoch 78/100 | Training Loss : 0.4339 | Training Accuracy : 77.09 % | Validation Loss : 0.4686 | Validation Accuracy : 75.69 %
# Epoch 79/100 | Training Loss : 0.4332 | Training Accuracy : 77.39 % | Validation Loss : 0.4691 | Validation Accuracy : 74.66 %
# Epoch 80/100 | Training Loss : 0.4354 | Training Accuracy : 77.59 % | Validation Loss : 0.4703 | Validation Accuracy : 74.48 %
# Epoch 81/100 | Training Loss : 0.4482 | Training Accuracy : 76.69 % | Validation Loss : 0.4686 | Validation Accuracy : 75.52 %
# Epoch 82/100 | Training Loss : 0.4434 | Training Accuracy : 77.76 % | Validation Loss : 0.4719 | Validation Accuracy : 74.66 %
# Epoch 83/100 | Training Loss : 0.4387 | Training Accuracy : 77.49 % | Validation Loss : 0.4690 | Validation Accuracy : 74.66 %
# Epoch 84/100 | Training Loss : 0.4428 | Training Accuracy : 77.61 % | Validation Loss : 0.4687 | Validation Accuracy : 74.83 %
# Epoch 85/100 | Training Loss : 0.4351 | Training Accuracy : 77.47 % | Validation Loss : 0.4701 | Validation Accuracy : 75.17 %
# Epoch 86/100 | Training Loss : 0.4388 | Training Accuracy : 77.68 % | Validation Loss : 0.4690 | Validation Accuracy : 74.66 %
# Epoch 87/100 | Training Loss : 0.4316 | Training Accuracy : 77.82 % | Validation Loss : 0.4686 | Validation Accuracy : 75.86 %
# Epoch 88/100 | Training Loss : 0.4365 | Training Accuracy : 76.95 % | Validation Loss : 0.4699 | Validation Accuracy : 75.17 %
# Epoch 89/100 | Training Loss : 0.4421 | Training Accuracy : 76.93 % | Validation Loss : 0.4697 | Validation Accuracy : 74.31 %
# Epoch 90/100 | Training Loss : 0.4336 | Training Accuracy : 77.36 % | Validation Loss : 0.4727 | Validation Accuracy : 74.83 %
# Epoch 91/100 | Training Loss : 0.4386 | Training Accuracy : 77.61 % | Validation Loss : 0.4673 | Validation Accuracy : 75.69 %
# Epoch 92/100 | Training Loss : 0.4318 | Training Accuracy : 76.86 % | Validation Loss : 0.4691 | Validation Accuracy : 75.34 %
# Epoch 93/100 | Training Loss : 0.4323 | Training Accuracy : 77.49 % | Validation Loss : 0.4718 | Validation Accuracy : 75.34 %
# Epoch 94/100 | Training Loss : 0.4360 | Training Accuracy : 77.68 % | Validation Loss : 0.4714 | Validation Accuracy : 74.83 %
# Epoch 95/100 | Training Loss : 0.4435 | Training Accuracy : 76.69 % | Validation Loss : 0.4684 | Validation Accuracy : 75.34 %
# Epoch 96/100 | Training Loss : 0.4341 | Training Accuracy : 77.30 % | Validation Loss : 0.4705 | Validation Accuracy : 74.48 %
# Epoch 97/100 | Training Loss : 0.4369 | Training Accuracy : 77.20 % | Validation Loss : 0.4708 | Validation Accuracy : 76.03 %
# Epoch 98/100 | Training Loss : 0.4410 | Training Accuracy : 76.84 % | Validation Loss : 0.4688 | Validation Accuracy : 74.31 %
# Epoch 99/100 | Training Loss : 0.4392 | Training Accuracy : 77.30 % | Validation Loss : 0.4691 | Validation Accuracy : 75.17 %
# Epoch 100/100 | Training Loss : 0.4358 | Training Accuracy : 77.09 % | Validation Loss : 0.4686 | Validation Accuracy : 75.69 %
# Test Subject : 1 | Test Loss : 0.5526 | Test Accuracy : 69.31 %
#
# ################################
#
# ===== Fold 2
# ===== Seed : 44
# ===== Training Subject : 1, 3, 4, 5, 6, 7, 8, 9
# ===== Test Subject : 2
#
# Epoch 1/100 | Training Loss : 0.4395 | Training Accuracy : 77.99 % | Validation Loss : 0.4074 | Validation Accuracy : 77.40 %
# Epoch 2/100 | Training Loss : 0.4382 | Training Accuracy : 77.78 % | Validation Loss : 0.4081 | Validation Accuracy : 76.88 %
# Epoch 3/100 | Training Loss : 0.4325 | Training Accuracy : 78.35 % | Validation Loss : 0.4012 | Validation Accuracy : 80.31 %
# Epoch 4/100 | Training Loss : 0.4435 | Training Accuracy : 77.23 % | Validation Loss : 0.4074 | Validation Accuracy : 78.60 %
# Epoch 5/100 | Training Loss : 0.4344 | Training Accuracy : 78.31 % | Validation Loss : 0.4077 | Validation Accuracy : 78.42 %
# Epoch 6/100 | Training Loss : 0.4468 | Training Accuracy : 77.04 % | Validation Loss : 0.4163 | Validation Accuracy : 77.74 %
# Epoch 7/100 | Training Loss : 0.4289 | Training Accuracy : 78.22 % | Validation Loss : 0.4048 | Validation Accuracy : 80.48 %
# Epoch 8/100 | Training Loss : 0.4404 | Training Accuracy : 78.03 % | Validation Loss : 0.4187 | Validation Accuracy : 78.60 %
# Epoch 9/100 | Training Loss : 0.4278 | Training Accuracy : 79.03 % | Validation Loss : 0.4108 | Validation Accuracy : 78.94 %
# Epoch 10/100 | Training Loss : 0.4313 | Training Accuracy : 77.97 % | Validation Loss : 0.4127 | Validation Accuracy : 79.45 %
# Epoch 11/100 | Training Loss : 0.4219 | Training Accuracy : 79.47 % | Validation Loss : 0.4018 | Validation Accuracy : 79.11 %
# Epoch 12/100 | Training Loss : 0.4264 | Training Accuracy : 78.52 % | Validation Loss : 0.4052 | Validation Accuracy : 79.62 %
# Epoch 13/100 | Training Loss : 0.4167 | Training Accuracy : 78.82 % | Validation Loss : 0.3957 | Validation Accuracy : 79.79 %
# Epoch 14/100 | Training Loss : 0.4235 | Training Accuracy : 78.82 % | Validation Loss : 0.4156 | Validation Accuracy : 78.94 %
# Epoch 15/100 | Training Loss : 0.4118 | Training Accuracy : 80.04 % | Validation Loss : 0.3926 | Validation Accuracy : 80.99 %
# Epoch 16/100 | Training Loss : 0.4143 | Training Accuracy : 79.64 % | Validation Loss : 0.3951 | Validation Accuracy : 79.62 %
# Epoch 17/100 | Training Loss : 0.4155 | Training Accuracy : 79.57 % | Validation Loss : 0.4028 | Validation Accuracy : 78.77 %
# Epoch 18/100 | Training Loss : 0.4197 | Training Accuracy : 79.11 % | Validation Loss : 0.3975 | Validation Accuracy : 79.79 %
# Epoch 19/100 | Training Loss : 0.4132 | Training Accuracy : 79.43 % | Validation Loss : 0.3924 | Validation Accuracy : 81.16 %
# Epoch 20/100 | Training Loss : 0.4125 | Training Accuracy : 79.83 % | Validation Loss : 0.3946 | Validation Accuracy : 80.48 %
# Epoch 21/100 | Training Loss : 0.4131 | Training Accuracy : 79.76 % | Validation Loss : 0.3988 | Validation Accuracy : 79.97 %
# Epoch 22/100 | Training Loss : 0.4136 | Training Accuracy : 79.49 % | Validation Loss : 0.3947 | Validation Accuracy : 80.48 %
# Epoch 23/100 | Training Loss : 0.4090 | Training Accuracy : 79.97 % | Validation Loss : 0.3947 | Validation Accuracy : 81.16 %
# Epoch 24/100 | Training Loss : 0.4140 | Training Accuracy : 79.68 % | Validation Loss : 0.3890 | Validation Accuracy : 80.65 %
# Epoch 25/100 | Training Loss : 0.4134 | Training Accuracy : 79.95 % | Validation Loss : 0.4092 | Validation Accuracy : 80.31 %
# Epoch 26/100 | Training Loss : 0.4123 | Training Accuracy : 80.25 % | Validation Loss : 0.3939 | Validation Accuracy : 81.34 %
# Epoch 27/100 | Training Loss : 0.4159 | Training Accuracy : 79.91 % | Validation Loss : 0.3950 | Validation Accuracy : 80.31 %
# Epoch 28/100 | Training Loss : 0.4032 | Training Accuracy : 80.06 % | Validation Loss : 0.3897 | Validation Accuracy : 79.79 %
# Epoch 29/100 | Training Loss : 0.4134 | Training Accuracy : 79.66 % | Validation Loss : 0.3926 | Validation Accuracy : 80.14 %
# Epoch 30/100 | Training Loss : 0.4102 | Training Accuracy : 79.85 % | Validation Loss : 0.3993 | Validation Accuracy : 80.65 %
# Epoch 31/100 | Training Loss : 0.4054 | Training Accuracy : 80.48 % | Validation Loss : 0.3889 | Validation Accuracy : 80.65 %
# Epoch 32/100 | Training Loss : 0.3965 | Training Accuracy : 80.97 % | Validation Loss : 0.4060 | Validation Accuracy : 79.97 %
# Epoch 33/100 | Training Loss : 0.4009 | Training Accuracy : 80.04 % | Validation Loss : 0.3878 | Validation Accuracy : 80.99 %
# Epoch 34/100 | Training Loss : 0.3979 | Training Accuracy : 80.52 % | Validation Loss : 0.3860 | Validation Accuracy : 80.82 %
# Epoch 35/100 | Training Loss : 0.3895 | Training Accuracy : 80.42 % | Validation Loss : 0.3878 | Validation Accuracy : 80.82 %
# Epoch 36/100 | Training Loss : 0.4073 | Training Accuracy : 79.78 % | Validation Loss : 0.4043 | Validation Accuracy : 80.48 %
# Epoch 37/100 | Training Loss : 0.4031 | Training Accuracy : 79.74 % | Validation Loss : 0.4004 | Validation Accuracy : 79.97 %
# Epoch 38/100 | Training Loss : 0.4021 | Training Accuracy : 80.35 % | Validation Loss : 0.3884 | Validation Accuracy : 80.65 %
# Epoch 39/100 | Training Loss : 0.4077 | Training Accuracy : 79.95 % | Validation Loss : 0.3860 | Validation Accuracy : 80.48 %
# Epoch 40/100 | Training Loss : 0.4002 | Training Accuracy : 80.50 % | Validation Loss : 0.3844 | Validation Accuracy : 80.31 %
# Epoch 41/100 | Training Loss : 0.3983 | Training Accuracy : 80.16 % | Validation Loss : 0.3838 | Validation Accuracy : 79.97 %
# Epoch 42/100 | Training Loss : 0.4008 | Training Accuracy : 80.27 % | Validation Loss : 0.3828 | Validation Accuracy : 79.62 %
# Epoch 43/100 | Training Loss : 0.3931 | Training Accuracy : 81.07 % | Validation Loss : 0.3842 | Validation Accuracy : 80.82 %
# Epoch 44/100 | Training Loss : 0.3955 | Training Accuracy : 80.54 % | Validation Loss : 0.3847 | Validation Accuracy : 79.79 %
# Epoch 45/100 | Training Loss : 0.3953 | Training Accuracy : 80.48 % | Validation Loss : 0.3966 | Validation Accuracy : 79.79 %
# Epoch 46/100 | Training Loss : 0.3984 | Training Accuracy : 80.50 % | Validation Loss : 0.3972 | Validation Accuracy : 80.99 %
# Epoch 47/100 | Training Loss : 0.3932 | Training Accuracy : 80.94 % | Validation Loss : 0.3918 | Validation Accuracy : 80.31 %
# Epoch 48/100 | Training Loss : 0.3932 | Training Accuracy : 80.86 % | Validation Loss : 0.3821 | Validation Accuracy : 79.79 %
# Epoch 49/100 | Training Loss : 0.3880 | Training Accuracy : 81.01 % | Validation Loss : 0.3788 | Validation Accuracy : 80.99 %
# Epoch 50/100 | Training Loss : 0.3905 | Training Accuracy : 81.05 % | Validation Loss : 0.3860 | Validation Accuracy : 79.97 %
# Epoch 51/100 | Training Loss : 0.3886 | Training Accuracy : 80.84 % | Validation Loss : 0.3834 | Validation Accuracy : 82.19 %
# Epoch 52/100 | Training Loss : 0.3939 | Training Accuracy : 80.48 % | Validation Loss : 0.3836 | Validation Accuracy : 81.16 %
# Epoch 53/100 | Training Loss : 0.3836 | Training Accuracy : 80.86 % | Validation Loss : 0.3873 | Validation Accuracy : 79.45 %
# Epoch 54/100 | Training Loss : 0.3949 | Training Accuracy : 80.56 % | Validation Loss : 0.3913 | Validation Accuracy : 79.62 %
# Epoch 55/100 | Training Loss : 0.3967 | Training Accuracy : 80.59 % | Validation Loss : 0.3891 | Validation Accuracy : 79.45 %
# Epoch 56/100 | Training Loss : 0.3881 | Training Accuracy : 81.16 % | Validation Loss : 0.3943 | Validation Accuracy : 79.45 %
# Epoch 57/100 | Training Loss : 0.3852 | Training Accuracy : 81.62 % | Validation Loss : 0.3911 | Validation Accuracy : 79.28 %
# Epoch 58/100 | Training Loss : 0.3974 | Training Accuracy : 80.37 % | Validation Loss : 0.3894 | Validation Accuracy : 79.79 %
# Epoch 59/100 | Training Loss : 0.3803 | Training Accuracy : 81.53 % | Validation Loss : 0.3894 | Validation Accuracy : 80.65 %
# Epoch 60/100 | Training Loss : 0.3824 | Training Accuracy : 81.83 % | Validation Loss : 0.3949 | Validation Accuracy : 81.85 %
# Epoch 61/100 | Training Loss : 0.3821 | Training Accuracy : 81.60 % | Validation Loss : 0.3906 | Validation Accuracy : 81.16 %
# Epoch 62/100 | Training Loss : 0.3914 | Training Accuracy : 80.46 % | Validation Loss : 0.3916 | Validation Accuracy : 81.51 %
# Epoch 63/100 | Training Loss : 0.3827 | Training Accuracy : 81.64 % | Validation Loss : 0.3846 | Validation Accuracy : 79.97 %
# Epoch 64/100 | Training Loss : 0.3844 | Training Accuracy : 80.97 % | Validation Loss : 0.3878 | Validation Accuracy : 81.16 %
# Epoch 65/100 | Training Loss : 0.3821 | Training Accuracy : 80.84 % | Validation Loss : 0.3921 | Validation Accuracy : 81.68 %
# Epoch 66/100 | Training Loss : 0.3879 | Training Accuracy : 80.71 % | Validation Loss : 0.3908 | Validation Accuracy : 81.68 %
# Epoch 67/100 | Training Loss : 0.3901 | Training Accuracy : 81.03 % | Validation Loss : 0.3866 | Validation Accuracy : 80.48 %
# Epoch 68/100 | Training Loss : 0.3847 | Training Accuracy : 82.06 % | Validation Loss : 0.3847 | Validation Accuracy : 80.65 %
# Epoch 69/100 | Training Loss : 0.3820 | Training Accuracy : 81.70 % | Validation Loss : 0.3842 | Validation Accuracy : 80.82 %
# Epoch 70/100 | Training Loss : 0.3784 | Training Accuracy : 81.07 % | Validation Loss : 0.3849 | Validation Accuracy : 80.82 %
# Epoch 71/100 | Training Loss : 0.3787 | Training Accuracy : 81.45 % | Validation Loss : 0.3856 | Validation Accuracy : 80.99 %
# Epoch 72/100 | Training Loss : 0.3817 | Training Accuracy : 81.58 % | Validation Loss : 0.3853 | Validation Accuracy : 80.82 %
# Epoch 73/100 | Training Loss : 0.3841 | Training Accuracy : 81.35 % | Validation Loss : 0.3839 | Validation Accuracy : 80.82 %
# Epoch 74/100 | Training Loss : 0.3787 | Training Accuracy : 81.34 % | Validation Loss : 0.3844 | Validation Accuracy : 81.16 %
# Epoch 75/100 | Training Loss : 0.3811 | Training Accuracy : 81.91 % | Validation Loss : 0.3849 | Validation Accuracy : 80.82 %
# Epoch 76/100 | Training Loss : 0.3830 | Training Accuracy : 81.47 % | Validation Loss : 0.3893 | Validation Accuracy : 81.16 %
# Epoch 77/100 | Training Loss : 0.3826 | Training Accuracy : 81.28 % | Validation Loss : 0.3846 | Validation Accuracy : 80.99 %
# Epoch 78/100 | Training Loss : 0.3823 | Training Accuracy : 80.99 % | Validation Loss : 0.3874 | Validation Accuracy : 80.99 %
# Epoch 79/100 | Training Loss : 0.3755 | Training Accuracy : 81.51 % | Validation Loss : 0.3859 | Validation Accuracy : 80.99 %
# Epoch 80/100 | Training Loss : 0.3838 | Training Accuracy : 81.26 % | Validation Loss : 0.3852 | Validation Accuracy : 80.82 %
# Epoch 81/100 | Training Loss : 0.3895 | Training Accuracy : 81.15 % | Validation Loss : 0.3869 | Validation Accuracy : 80.82 %
# Epoch 82/100 | Training Loss : 0.3815 | Training Accuracy : 81.56 % | Validation Loss : 0.3933 | Validation Accuracy : 81.68 %
# Epoch 83/100 | Training Loss : 0.3795 | Training Accuracy : 81.16 % | Validation Loss : 0.3888 | Validation Accuracy : 80.99 %
# Epoch 84/100 | Training Loss : 0.3850 | Training Accuracy : 81.07 % | Validation Loss : 0.3831 | Validation Accuracy : 80.48 %
# Epoch 85/100 | Training Loss : 0.3851 | Training Accuracy : 81.35 % | Validation Loss : 0.3846 | Validation Accuracy : 80.14 %
# Epoch 86/100 | Training Loss : 0.3903 | Training Accuracy : 81.03 % | Validation Loss : 0.3848 | Validation Accuracy : 80.99 %
# Epoch 87/100 | Training Loss : 0.3811 | Training Accuracy : 81.43 % | Validation Loss : 0.3881 | Validation Accuracy : 81.34 %
# Epoch 88/100 | Training Loss : 0.3811 | Training Accuracy : 81.35 % | Validation Loss : 0.3868 | Validation Accuracy : 81.16 %
# Epoch 89/100 | Training Loss : 0.3835 | Training Accuracy : 81.15 % | Validation Loss : 0.3908 | Validation Accuracy : 81.16 %
# Epoch 90/100 | Training Loss : 0.3841 | Training Accuracy : 81.62 % | Validation Loss : 0.3856 | Validation Accuracy : 79.45 %
# Epoch 91/100 | Training Loss : 0.3841 | Training Accuracy : 81.35 % | Validation Loss : 0.3850 | Validation Accuracy : 80.31 %
# Epoch 92/100 | Training Loss : 0.3844 | Training Accuracy : 81.81 % | Validation Loss : 0.3847 | Validation Accuracy : 79.62 %
# Epoch 93/100 | Training Loss : 0.3809 | Training Accuracy : 81.70 % | Validation Loss : 0.3855 | Validation Accuracy : 79.62 %
# Epoch 94/100 | Training Loss : 0.3854 | Training Accuracy : 81.34 % | Validation Loss : 0.3898 | Validation Accuracy : 80.99 %
# Epoch 95/100 | Training Loss : 0.3884 | Training Accuracy : 81.20 % | Validation Loss : 0.3912 | Validation Accuracy : 81.34 %
# Epoch 96/100 | Training Loss : 0.3723 | Training Accuracy : 81.47 % | Validation Loss : 0.3833 | Validation Accuracy : 79.97 %
# Epoch 97/100 | Training Loss : 0.3862 | Training Accuracy : 81.11 % | Validation Loss : 0.3848 | Validation Accuracy : 80.48 %
# Epoch 98/100 | Training Loss : 0.3830 | Training Accuracy : 81.09 % | Validation Loss : 0.3857 | Validation Accuracy : 80.99 %
# Epoch 99/100 | Training Loss : 0.3906 | Training Accuracy : 81.11 % | Validation Loss : 0.3878 | Validation Accuracy : 81.16 %
# Epoch 100/100 | Training Loss : 0.3821 | Training Accuracy : 81.64 % | Validation Loss : 0.3855 | Validation Accuracy : 81.16 %
# Test Subject : 2 | Test Loss : 0.7370 | Test Accuracy : 58.09 %
#
# ################################
#
# ===== Fold 3
# ===== Seed : 45
# ===== Training Subject : 1, 2, 4, 5, 6, 7, 8, 9
# ===== Test Subject : 3
#
# Epoch 1/100 | Training Loss : 0.4196 | Training Accuracy : 79.98 % | Validation Loss : 0.3707 | Validation Accuracy : 83.97 %
# Epoch 2/100 | Training Loss : 0.4109 | Training Accuracy : 80.40 % | Validation Loss : 0.3616 | Validation Accuracy : 82.93 %
# Epoch 3/100 | Training Loss : 0.4068 | Training Accuracy : 80.44 % | Validation Loss : 0.3726 | Validation Accuracy : 81.03 %
# Epoch 4/100 | Training Loss : 0.4022 | Training Accuracy : 80.42 % | Validation Loss : 0.3607 | Validation Accuracy : 82.93 %
# Epoch 5/100 | Training Loss : 0.4114 | Training Accuracy : 79.64 % | Validation Loss : 0.3693 | Validation Accuracy : 81.90 %
# Epoch 6/100 | Training Loss : 0.4141 | Training Accuracy : 80.40 % | Validation Loss : 0.3660 | Validation Accuracy : 82.41 %
# Epoch 7/100 | Training Loss : 0.4072 | Training Accuracy : 80.02 % | Validation Loss : 0.3761 | Validation Accuracy : 81.21 %
# Epoch 8/100 | Training Loss : 0.4047 | Training Accuracy : 80.50 % | Validation Loss : 0.3653 | Validation Accuracy : 82.93 %
# Epoch 9/100 | Training Loss : 0.4072 | Training Accuracy : 80.42 % | Validation Loss : 0.3747 | Validation Accuracy : 82.59 %
# Epoch 10/100 | Training Loss : 0.4134 | Training Accuracy : 80.31 % | Validation Loss : 0.3760 | Validation Accuracy : 81.03 %
# Epoch 11/100 | Training Loss : 0.3904 | Training Accuracy : 81.09 % | Validation Loss : 0.3561 | Validation Accuracy : 82.93 %
# Epoch 12/100 | Training Loss : 0.3862 | Training Accuracy : 81.53 % | Validation Loss : 0.3589 | Validation Accuracy : 82.93 %
# Epoch 13/100 | Training Loss : 0.3949 | Training Accuracy : 80.94 % | Validation Loss : 0.3691 | Validation Accuracy : 81.38 %
# Epoch 14/100 | Training Loss : 0.3923 | Training Accuracy : 81.26 % | Validation Loss : 0.3622 | Validation Accuracy : 82.76 %
# Epoch 15/100 | Training Loss : 0.3803 | Training Accuracy : 81.63 % | Validation Loss : 0.3601 | Validation Accuracy : 82.93 %
# Epoch 16/100 | Training Loss : 0.3977 | Training Accuracy : 80.67 % | Validation Loss : 0.3569 | Validation Accuracy : 83.79 %
# Epoch 17/100 | Training Loss : 0.3915 | Training Accuracy : 81.80 % | Validation Loss : 0.3655 | Validation Accuracy : 82.93 %
# Epoch 18/100 | Training Loss : 0.3833 | Training Accuracy : 81.59 % | Validation Loss : 0.3610 | Validation Accuracy : 82.76 %
# Epoch 19/100 | Training Loss : 0.3746 | Training Accuracy : 82.07 % | Validation Loss : 0.3555 | Validation Accuracy : 82.41 %
# Epoch 20/100 | Training Loss : 0.3860 | Training Accuracy : 81.21 % | Validation Loss : 0.3575 | Validation Accuracy : 82.76 %
# Epoch 21/100 | Training Loss : 0.3766 | Training Accuracy : 81.65 % | Validation Loss : 0.3598 | Validation Accuracy : 82.24 %
# Epoch 22/100 | Training Loss : 0.3682 | Training Accuracy : 82.43 % | Validation Loss : 0.3610 | Validation Accuracy : 82.76 %
# Epoch 23/100 | Training Loss : 0.3780 | Training Accuracy : 81.99 % | Validation Loss : 0.3703 | Validation Accuracy : 81.38 %
# Epoch 24/100 | Training Loss : 0.3821 | Training Accuracy : 82.09 % | Validation Loss : 0.3580 | Validation Accuracy : 82.59 %
# Epoch 25/100 | Training Loss : 0.3790 | Training Accuracy : 81.90 % | Validation Loss : 0.3555 | Validation Accuracy : 82.76 %
# Epoch 26/100 | Training Loss : 0.3716 | Training Accuracy : 82.30 % | Validation Loss : 0.3553 | Validation Accuracy : 83.10 %
# Epoch 27/100 | Training Loss : 0.3714 | Training Accuracy : 81.97 % | Validation Loss : 0.3533 | Validation Accuracy : 82.76 %
# Epoch 28/100 | Training Loss : 0.3747 | Training Accuracy : 81.69 % | Validation Loss : 0.3567 | Validation Accuracy : 82.24 %
# Epoch 29/100 | Training Loss : 0.3713 | Training Accuracy : 82.45 % | Validation Loss : 0.3567 | Validation Accuracy : 82.93 %
# Epoch 30/100 | Training Loss : 0.3763 | Training Accuracy : 81.67 % | Validation Loss : 0.3536 | Validation Accuracy : 83.28 %
# Epoch 31/100 | Training Loss : 0.3723 | Training Accuracy : 82.13 % | Validation Loss : 0.3559 | Validation Accuracy : 83.79 %
# Epoch 32/100 | Training Loss : 0.3636 | Training Accuracy : 82.34 % | Validation Loss : 0.3546 | Validation Accuracy : 83.62 %
# Epoch 33/100 | Training Loss : 0.3700 | Training Accuracy : 82.11 % | Validation Loss : 0.3545 | Validation Accuracy : 83.28 %
# Epoch 34/100 | Training Loss : 0.3721 | Training Accuracy : 82.30 % | Validation Loss : 0.3537 | Validation Accuracy : 82.93 %
# Epoch 35/100 | Training Loss : 0.3693 | Training Accuracy : 82.64 % | Validation Loss : 0.3528 | Validation Accuracy : 83.62 %
# Epoch 36/100 | Training Loss : 0.3721 | Training Accuracy : 82.61 % | Validation Loss : 0.3527 | Validation Accuracy : 83.62 %
# Epoch 37/100 | Training Loss : 0.3715 | Training Accuracy : 82.38 % | Validation Loss : 0.3549 | Validation Accuracy : 83.28 %
# Epoch 38/100 | Training Loss : 0.3716 | Training Accuracy : 82.18 % | Validation Loss : 0.3552 | Validation Accuracy : 83.28 %
# Epoch 39/100 | Training Loss : 0.3684 | Training Accuracy : 82.49 % | Validation Loss : 0.3528 | Validation Accuracy : 83.28 %
# Epoch 40/100 | Training Loss : 0.3673 | Training Accuracy : 82.26 % | Validation Loss : 0.3537 | Validation Accuracy : 83.62 %
# Epoch 41/100 | Training Loss : 0.3633 | Training Accuracy : 83.08 % | Validation Loss : 0.3522 | Validation Accuracy : 83.45 %
# Epoch 42/100 | Training Loss : 0.3681 | Training Accuracy : 82.53 % | Validation Loss : 0.3537 | Validation Accuracy : 83.62 %
# Epoch 43/100 | Training Loss : 0.3708 | Training Accuracy : 82.28 % | Validation Loss : 0.3528 | Validation Accuracy : 82.93 %
# Epoch 44/100 | Training Loss : 0.3734 | Training Accuracy : 82.09 % | Validation Loss : 0.3529 | Validation Accuracy : 83.62 %
# Epoch 45/100 | Training Loss : 0.3677 | Training Accuracy : 82.47 % | Validation Loss : 0.3531 | Validation Accuracy : 83.45 %
# Epoch 46/100 | Training Loss : 0.3636 | Training Accuracy : 82.72 % | Validation Loss : 0.3529 | Validation Accuracy : 82.93 %
# Epoch 47/100 | Training Loss : 0.3673 | Training Accuracy : 82.09 % | Validation Loss : 0.3544 | Validation Accuracy : 83.45 %
# Epoch 48/100 | Training Loss : 0.3699 | Training Accuracy : 82.32 % | Validation Loss : 0.3513 | Validation Accuracy : 83.10 %
# Epoch 49/100 | Training Loss : 0.3742 | Training Accuracy : 82.18 % | Validation Loss : 0.3528 | Validation Accuracy : 83.28 %
# Epoch 50/100 | Training Loss : 0.3635 | Training Accuracy : 82.41 % | Validation Loss : 0.3538 | Validation Accuracy : 83.79 %
# Epoch 51/100 | Training Loss : 0.3716 | Training Accuracy : 82.47 % | Validation Loss : 0.3550 | Validation Accuracy : 83.62 %
# Epoch 52/100 | Training Loss : 0.3659 | Training Accuracy : 82.11 % | Validation Loss : 0.3532 | Validation Accuracy : 83.45 %
# Epoch 53/100 | Training Loss : 0.3681 | Training Accuracy : 83.16 % | Validation Loss : 0.3528 | Validation Accuracy : 83.62 %
# Epoch 54/100 | Training Loss : 0.3689 | Training Accuracy : 82.39 % | Validation Loss : 0.3518 | Validation Accuracy : 83.45 %
# Epoch 55/100 | Training Loss : 0.3721 | Training Accuracy : 82.13 % | Validation Loss : 0.3534 | Validation Accuracy : 83.45 %
# Epoch 56/100 | Training Loss : 0.3660 | Training Accuracy : 82.70 % | Validation Loss : 0.3540 | Validation Accuracy : 83.62 %
# Epoch 57/100 | Training Loss : 0.3591 | Training Accuracy : 83.30 % | Validation Loss : 0.3542 | Validation Accuracy : 83.62 %
# Epoch 58/100 | Training Loss : 0.3562 | Training Accuracy : 83.08 % | Validation Loss : 0.3527 | Validation Accuracy : 83.79 %
# Epoch 59/100 | Training Loss : 0.3568 | Training Accuracy : 83.43 % | Validation Loss : 0.3533 | Validation Accuracy : 83.62 %
# Epoch 60/100 | Training Loss : 0.3705 | Training Accuracy : 82.64 % | Validation Loss : 0.3557 | Validation Accuracy : 82.93 %
# Epoch 61/100 | Training Loss : 0.3639 | Training Accuracy : 82.30 % | Validation Loss : 0.3573 | Validation Accuracy : 83.10 %
# Epoch 62/100 | Training Loss : 0.3687 | Training Accuracy : 81.82 % | Validation Loss : 0.3524 | Validation Accuracy : 83.28 %
# Epoch 63/100 | Training Loss : 0.3696 | Training Accuracy : 82.51 % | Validation Loss : 0.3541 | Validation Accuracy : 83.62 %
# Epoch 64/100 | Training Loss : 0.3605 | Training Accuracy : 82.55 % | Validation Loss : 0.3517 | Validation Accuracy : 83.45 %
# Epoch 65/100 | Training Loss : 0.3706 | Training Accuracy : 82.53 % | Validation Loss : 0.3526 | Validation Accuracy : 83.62 %
# Epoch 66/100 | Training Loss : 0.3647 | Training Accuracy : 82.43 % | Validation Loss : 0.3580 | Validation Accuracy : 82.76 %
# Epoch 67/100 | Training Loss : 0.3618 | Training Accuracy : 82.80 % | Validation Loss : 0.3516 | Validation Accuracy : 83.28 %
# Epoch 68/100 | Training Loss : 0.3608 | Training Accuracy : 82.28 % | Validation Loss : 0.3536 | Validation Accuracy : 83.28 %
# Epoch 69/100 | Training Loss : 0.3654 | Training Accuracy : 82.68 % | Validation Loss : 0.3538 | Validation Accuracy : 83.45 %
# Epoch 70/100 | Training Loss : 0.3674 | Training Accuracy : 82.43 % | Validation Loss : 0.3564 | Validation Accuracy : 82.93 %
# Epoch 71/100 | Training Loss : 0.3682 | Training Accuracy : 83.24 % | Validation Loss : 0.3526 | Validation Accuracy : 83.45 %
# Epoch 72/100 | Training Loss : 0.3624 | Training Accuracy : 82.53 % | Validation Loss : 0.3530 | Validation Accuracy : 83.62 %
# Epoch 73/100 | Training Loss : 0.3684 | Training Accuracy : 82.01 % | Validation Loss : 0.3525 | Validation Accuracy : 83.28 %
# Epoch 74/100 | Training Loss : 0.3649 | Training Accuracy : 82.47 % | Validation Loss : 0.3531 | Validation Accuracy : 83.45 %
# Epoch 75/100 | Training Loss : 0.3674 | Training Accuracy : 81.95 % | Validation Loss : 0.3511 | Validation Accuracy : 83.28 %
# Epoch 76/100 | Training Loss : 0.3613 | Training Accuracy : 82.51 % | Validation Loss : 0.3521 | Validation Accuracy : 83.45 %
# Epoch 77/100 | Training Loss : 0.3611 | Training Accuracy : 82.91 % | Validation Loss : 0.3516 | Validation Accuracy : 83.28 %
# Epoch 78/100 | Training Loss : 0.3652 | Training Accuracy : 83.10 % | Validation Loss : 0.3572 | Validation Accuracy : 83.10 %
# Epoch 79/100 | Training Loss : 0.3645 | Training Accuracy : 82.91 % | Validation Loss : 0.3523 | Validation Accuracy : 83.45 %
# Epoch 80/100 | Training Loss : 0.3600 | Training Accuracy : 82.97 % | Validation Loss : 0.3532 | Validation Accuracy : 83.28 %
# Epoch 81/100 | Training Loss : 0.3698 | Training Accuracy : 81.88 % | Validation Loss : 0.3530 | Validation Accuracy : 83.45 %
# Epoch 82/100 | Training Loss : 0.3697 | Training Accuracy : 82.16 % | Validation Loss : 0.3520 | Validation Accuracy : 83.45 %
# Epoch 83/100 | Training Loss : 0.3559 | Training Accuracy : 82.68 % | Validation Loss : 0.3525 | Validation Accuracy : 83.45 %
# Epoch 84/100 | Training Loss : 0.3661 | Training Accuracy : 82.43 % | Validation Loss : 0.3527 | Validation Accuracy : 83.45 %
# Epoch 85/100 | Training Loss : 0.3659 | Training Accuracy : 81.93 % | Validation Loss : 0.3522 | Validation Accuracy : 83.45 %
# Epoch 86/100 | Training Loss : 0.3624 | Training Accuracy : 82.64 % | Validation Loss : 0.3540 | Validation Accuracy : 83.45 %
# Epoch 87/100 | Training Loss : 0.3627 | Training Accuracy : 82.43 % | Validation Loss : 0.3532 | Validation Accuracy : 83.79 %
# Epoch 88/100 | Training Loss : 0.3673 | Training Accuracy : 82.43 % | Validation Loss : 0.3514 | Validation Accuracy : 83.28 %
# Epoch 89/100 | Training Loss : 0.3618 | Training Accuracy : 82.72 % | Validation Loss : 0.3526 | Validation Accuracy : 83.62 %
# Epoch 90/100 | Training Loss : 0.3716 | Training Accuracy : 82.24 % | Validation Loss : 0.3529 | Validation Accuracy : 83.28 %
# Epoch 91/100 | Training Loss : 0.3666 | Training Accuracy : 82.64 % | Validation Loss : 0.3569 | Validation Accuracy : 82.59 %
# Epoch 92/100 | Training Loss : 0.3677 | Training Accuracy : 82.18 % | Validation Loss : 0.3521 | Validation Accuracy : 83.28 %
# Epoch 93/100 | Training Loss : 0.3652 | Training Accuracy : 82.36 % | Validation Loss : 0.3532 | Validation Accuracy : 83.45 %
# Epoch 94/100 | Training Loss : 0.3608 | Training Accuracy : 82.49 % | Validation Loss : 0.3528 | Validation Accuracy : 83.45 %
# Epoch 95/100 | Training Loss : 0.3652 | Training Accuracy : 82.59 % | Validation Loss : 0.3545 | Validation Accuracy : 82.93 %
# Epoch 96/100 | Training Loss : 0.3683 | Training Accuracy : 82.84 % | Validation Loss : 0.3529 | Validation Accuracy : 83.45 %
# Epoch 97/100 | Training Loss : 0.3599 | Training Accuracy : 82.57 % | Validation Loss : 0.3519 | Validation Accuracy : 83.45 %
# Epoch 98/100 | Training Loss : 0.3604 | Training Accuracy : 82.82 % | Validation Loss : 0.3543 | Validation Accuracy : 82.93 %
# Epoch 99/100 | Training Loss : 0.3711 | Training Accuracy : 82.26 % | Validation Loss : 0.3533 | Validation Accuracy : 83.45 %
# Epoch 100/100 | Training Loss : 0.3723 | Training Accuracy : 82.13 % | Validation Loss : 0.3520 | Validation Accuracy : 83.62 %
# Test Subject : 3 | Test Loss : 0.7390 | Test Accuracy : 57.92 %
#
# ################################
#
# ===== Fold 4
# ===== Seed : 46
# ===== Training Subject : 1, 2, 3, 5, 6, 7, 8, 9
# ===== Test Subject : 4
#
# Epoch 1/100 | Training Loss : 0.4656 | Training Accuracy : 75.61 % | Validation Loss : 0.3926 | Validation Accuracy : 79.76 %
# Epoch 2/100 | Training Loss : 0.4599 | Training Accuracy : 77.16 % | Validation Loss : 0.4130 | Validation Accuracy : 80.28 %
# Epoch 3/100 | Training Loss : 0.4488 | Training Accuracy : 77.45 % | Validation Loss : 0.4165 | Validation Accuracy : 79.41 %
# Epoch 4/100 | Training Loss : 0.4491 | Training Accuracy : 76.36 % | Validation Loss : 0.4090 | Validation Accuracy : 79.76 %
# Epoch 5/100 | Training Loss : 0.4556 | Training Accuracy : 76.45 % | Validation Loss : 0.4267 | Validation Accuracy : 79.07 %
# Epoch 6/100 | Training Loss : 0.4520 | Training Accuracy : 76.89 % | Validation Loss : 0.4140 | Validation Accuracy : 79.24 %
# Epoch 7/100 | Training Loss : 0.4401 | Training Accuracy : 78.10 % | Validation Loss : 0.4077 | Validation Accuracy : 79.93 %
# Epoch 8/100 | Training Loss : 0.4321 | Training Accuracy : 78.34 % | Validation Loss : 0.4048 | Validation Accuracy : 80.80 %
# Epoch 9/100 | Training Loss : 0.4328 | Training Accuracy : 78.07 % | Validation Loss : 0.4002 | Validation Accuracy : 78.72 %
# Epoch 10/100 | Training Loss : 0.4397 | Training Accuracy : 77.74 % | Validation Loss : 0.4015 | Validation Accuracy : 78.55 %
# Epoch 11/100 | Training Loss : 0.4255 | Training Accuracy : 78.55 % | Validation Loss : 0.4117 | Validation Accuracy : 81.49 %
# Epoch 12/100 | Training Loss : 0.4382 | Training Accuracy : 77.70 % | Validation Loss : 0.4041 | Validation Accuracy : 80.28 %
# Epoch 13/100 | Training Loss : 0.4341 | Training Accuracy : 77.41 % | Validation Loss : 0.3974 | Validation Accuracy : 80.28 %
# Epoch 14/100 | Training Loss : 0.4267 | Training Accuracy : 78.07 % | Validation Loss : 0.3939 | Validation Accuracy : 79.93 %
# Epoch 15/100 | Training Loss : 0.4289 | Training Accuracy : 77.68 % | Validation Loss : 0.4030 | Validation Accuracy : 81.31 %
# Epoch 16/100 | Training Loss : 0.4312 | Training Accuracy : 78.20 % | Validation Loss : 0.3974 | Validation Accuracy : 80.10 %
# Epoch 17/100 | Training Loss : 0.4281 | Training Accuracy : 78.26 % | Validation Loss : 0.4017 | Validation Accuracy : 79.58 %
# Epoch 18/100 | Training Loss : 0.4259 | Training Accuracy : 78.51 % | Validation Loss : 0.3951 | Validation Accuracy : 80.28 %
# Epoch 19/100 | Training Loss : 0.4221 | Training Accuracy : 78.47 % | Validation Loss : 0.3911 | Validation Accuracy : 80.10 %
# Epoch 20/100 | Training Loss : 0.4280 | Training Accuracy : 78.68 % | Validation Loss : 0.3919 | Validation Accuracy : 79.93 %
# Epoch 21/100 | Training Loss : 0.4298 | Training Accuracy : 77.99 % | Validation Loss : 0.4016 | Validation Accuracy : 80.80 %
# Epoch 22/100 | Training Loss : 0.4318 | Training Accuracy : 77.99 % | Validation Loss : 0.4010 | Validation Accuracy : 80.80 %
# Epoch 23/100 | Training Loss : 0.4264 | Training Accuracy : 78.45 % | Validation Loss : 0.4070 | Validation Accuracy : 79.58 %
# Epoch 24/100 | Training Loss : 0.4175 | Training Accuracy : 78.76 % | Validation Loss : 0.3917 | Validation Accuracy : 80.10 %
# Epoch 25/100 | Training Loss : 0.4230 | Training Accuracy : 78.41 % | Validation Loss : 0.3993 | Validation Accuracy : 80.28 %
# Epoch 26/100 | Training Loss : 0.4132 | Training Accuracy : 79.22 % | Validation Loss : 0.3920 | Validation Accuracy : 78.89 %
# Epoch 27/100 | Training Loss : 0.4165 | Training Accuracy : 79.14 % | Validation Loss : 0.4002 | Validation Accuracy : 80.45 %
# Epoch 28/100 | Training Loss : 0.4227 | Training Accuracy : 77.93 % | Validation Loss : 0.3914 | Validation Accuracy : 79.41 %
# Epoch 29/100 | Training Loss : 0.4257 | Training Accuracy : 78.53 % | Validation Loss : 0.3901 | Validation Accuracy : 79.07 %
# Epoch 30/100 | Training Loss : 0.4156 | Training Accuracy : 78.84 % | Validation Loss : 0.3917 | Validation Accuracy : 79.76 %
# Epoch 31/100 | Training Loss : 0.4252 | Training Accuracy : 78.34 % | Validation Loss : 0.3956 | Validation Accuracy : 79.76 %
# Epoch 32/100 | Training Loss : 0.4231 | Training Accuracy : 78.22 % | Validation Loss : 0.3998 | Validation Accuracy : 80.10 %
# Epoch 33/100 | Training Loss : 0.4195 | Training Accuracy : 78.70 % | Validation Loss : 0.3954 | Validation Accuracy : 79.58 %
# Epoch 34/100 | Training Loss : 0.4168 | Training Accuracy : 78.84 % | Validation Loss : 0.3900 | Validation Accuracy : 80.45 %
# Epoch 35/100 | Training Loss : 0.4161 | Training Accuracy : 79.26 % | Validation Loss : 0.3915 | Validation Accuracy : 79.41 %
# ...
# Epoch 82/100 | Training Loss : 0.3404 | Training Accuracy : 83.20 % | Validation Loss : 0.3460 | Validation Accuracy : 81.08 %
# Epoch 83/100 | Training Loss : 0.3375 | Training Accuracy : 83.12 % | Validation Loss : 0.3439 | Validation Accuracy : 81.25 %
# Epoch 84/100 | Training Loss : 0.3298 | Training Accuracy : 83.55 % | Validation Loss : 0.3448 | Validation Accuracy : 81.25 %
# Epoch 85/100 | Training Loss : 0.3440 | Training Accuracy : 83.10 % | Validation Loss : 0.3423 | Validation Accuracy : 81.08 %
# Epoch 86/100 | Training Loss : 0.3344 | Training Accuracy : 83.93 % | Validation Loss : 0.3462 | Validation Accuracy : 80.90 %
# Epoch 87/100 | Training Loss : 0.3336 | Training Accuracy : 83.58 % | Validation Loss : 0.3428 | Validation Accuracy : 81.25 %
# Epoch 88/100 | Training Loss : 0.3347 | Training Accuracy : 83.33 % | Validation Loss : 0.3463 | Validation Accuracy : 81.25 %
# Epoch 89/100 | Training Loss : 0.3415 | Training Accuracy : 82.83 % | Validation Loss : 0.3462 | Validation Accuracy : 81.25 %
# Epoch 90/100 | Training Loss : 0.3400 | Training Accuracy : 82.64 % | Validation Loss : 0.3446 | Validation Accuracy : 80.73 %
# Epoch 91/100 | Training Loss : 0.3371 | Training Accuracy : 83.56 % | Validation Loss : 0.3445 | Validation Accuracy : 81.08 %
# Epoch 92/100 | Training Loss : 0.3334 | Training Accuracy : 83.78 % | Validation Loss : 0.3476 | Validation Accuracy : 80.38 %
# Epoch 93/100 | Training Loss : 0.3428 | Training Accuracy : 82.79 % | Validation Loss : 0.3459 | Validation Accuracy : 81.08 %
# Epoch 94/100 | Training Loss : 0.3320 | Training Accuracy : 84.09 % | Validation Loss : 0.3434 | Validation Accuracy : 81.25 %
# Epoch 95/100 | Training Loss : 0.3366 | Training Accuracy : 83.82 % | Validation Loss : 0.3460 | Validation Accuracy : 80.90 %
# Epoch 96/100 | Training Loss : 0.3378 | Training Accuracy : 83.45 % | Validation Loss : 0.3444 | Validation Accuracy : 81.42 %
# Epoch 97/100 | Training Loss : 0.3362 | Training Accuracy : 83.35 % | Validation Loss : 0.3449 | Validation Accuracy : 81.25 %
# Epoch 98/100 | Training Loss : 0.3365 | Training Accuracy : 83.06 % | Validation Loss : 0.3466 | Validation Accuracy : 81.08 %
# Epoch 99/100 | Training Loss : 0.3410 | Training Accuracy : 83.41 % | Validation Loss : 0.3481 | Validation Accuracy : 80.56 %
# Epoch 100/100 | Training Loss : 0.3394 | Training Accuracy : 83.29 % | Validation Loss : 0.3451 | Validation Accuracy : 81.25 %
# Test Subject : 8 | Test Loss : 0.5344 | Test Accuracy : 79.74 %
#
# ################################
#
# ===== Fold 9
# ===== Seed : 51
# ===== Training Subject : 1, 2, 3, 4, 5, 6, 7, 8
# ===== Test Subject : 9
#
# Epoch 1/100 | Training Loss : 0.3900 | Training Accuracy : 80.98 % | Validation Loss : 0.3441 | Validation Accuracy : 83.62 %
# Epoch 2/100 | Training Loss : 0.3802 | Training Accuracy : 80.63 % | Validation Loss : 0.3673 | Validation Accuracy : 82.07 %
# Epoch 3/100 | Training Loss : 0.3830 | Training Accuracy : 80.69 % | Validation Loss : 0.3776 | Validation Accuracy : 79.48 %
# Epoch 4/100 | Training Loss : 0.3757 | Training Accuracy : 81.25 % | Validation Loss : 0.3651 | Validation Accuracy : 81.21 %
# Epoch 5/100 | Training Loss : 0.3776 | Training Accuracy : 80.96 % | Validation Loss : 0.3668 | Validation Accuracy : 82.41 %
# Epoch 6/100 | Training Loss : 0.3798 | Training Accuracy : 81.03 % | Validation Loss : 0.3608 | Validation Accuracy : 83.28 %
# Epoch 7/100 | Training Loss : 0.3803 | Training Accuracy : 80.75 % | Validation Loss : 0.3682 | Validation Accuracy : 80.34 %
# Epoch 8/100 | Training Loss : 0.3630 | Training Accuracy : 81.67 % | Validation Loss : 0.3550 | Validation Accuracy : 82.07 %
# Epoch 9/100 | Training Loss : 0.3649 | Training Accuracy : 81.99 % | Validation Loss : 0.3564 | Validation Accuracy : 81.72 %
# Epoch 10/100 | Training Loss : 0.3709 | Training Accuracy : 81.32 % | Validation Loss : 0.3640 | Validation Accuracy : 80.52 %
# Epoch 11/100 | Training Loss : 0.3619 | Training Accuracy : 82.07 % | Validation Loss : 0.3706 | Validation Accuracy : 81.72 %
# Epoch 12/100 | Training Loss : 0.3646 | Training Accuracy : 81.38 % | Validation Loss : 0.3743 | Validation Accuracy : 81.21 %
# Epoch 13/100 | Training Loss : 0.3622 | Training Accuracy : 81.86 % | Validation Loss : 0.3641 | Validation Accuracy : 82.07 %
# Epoch 14/100 | Training Loss : 0.3508 | Training Accuracy : 82.87 % | Validation Loss : 0.3625 | Validation Accuracy : 82.41 %
# Epoch 15/100 | Training Loss : 0.3632 | Training Accuracy : 81.78 % | Validation Loss : 0.3630 | Validation Accuracy : 81.90 %
# Epoch 16/100 | Training Loss : 0.3496 | Training Accuracy : 81.99 % | Validation Loss : 0.3606 | Validation Accuracy : 82.41 %
# Epoch 17/100 | Training Loss : 0.3473 | Training Accuracy : 82.84 % | Validation Loss : 0.3630 | Validation Accuracy : 81.38 %
# Epoch 18/100 | Training Loss : 0.3555 | Training Accuracy : 81.88 % | Validation Loss : 0.3624 | Validation Accuracy : 81.90 %
# Epoch 19/100 | Training Loss : 0.3474 | Training Accuracy : 82.76 % | Validation Loss : 0.3643 | Validation Accuracy : 81.72 %
# Epoch 20/100 | Training Loss : 0.3487 | Training Accuracy : 81.93 % | Validation Loss : 0.3571 | Validation Accuracy : 82.76 %
# Epoch 21/100 | Training Loss : 0.3530 | Training Accuracy : 82.28 % | Validation Loss : 0.3547 | Validation Accuracy : 82.41 %
# Epoch 22/100 | Training Loss : 0.3498 | Training Accuracy : 82.97 % | Validation Loss : 0.3577 | Validation Accuracy : 81.38 %
# Epoch 23/100 | Training Loss : 0.3465 | Training Accuracy : 82.64 % | Validation Loss : 0.3606 | Validation Accuracy : 82.07 %
# Epoch 24/100 | Training Loss : 0.3430 | Training Accuracy : 82.34 % | Validation Loss : 0.3557 | Validation Accuracy : 81.90 %
# Epoch 25/100 | Training Loss : 0.3516 | Training Accuracy : 83.20 % | Validation Loss : 0.3664 | Validation Accuracy : 81.38 %
# Epoch 26/100 | Training Loss : 0.3459 | Training Accuracy : 82.59 % | Validation Loss : 0.3591 | Validation Accuracy : 81.72 %
# Epoch 27/100 | Training Loss : 0.3452 | Training Accuracy : 82.30 % | Validation Loss : 0.3590 | Validation Accuracy : 82.24 %
# Epoch 28/100 | Training Loss : 0.3380 | Training Accuracy : 83.33 % | Validation Loss : 0.3556 | Validation Accuracy : 83.10 %
# Epoch 29/100 | Training Loss : 0.3423 | Training Accuracy : 83.10 % | Validation Loss : 0.3583 | Validation Accuracy : 81.90 %
# Epoch 30/100 | Training Loss : 0.3524 | Training Accuracy : 82.43 % | Validation Loss : 0.3604 | Validation Accuracy : 82.24 %
# Epoch 31/100 | Training Loss : 0.3456 | Training Accuracy : 83.08 % | Validation Loss : 0.3612 | Validation Accuracy : 82.93 %
# Epoch 32/100 | Training Loss : 0.3463 | Training Accuracy : 82.85 % | Validation Loss : 0.3607 | Validation Accuracy : 81.90 %
# Epoch 33/100 | Training Loss : 0.3421 | Training Accuracy : 82.91 % | Validation Loss : 0.3630 | Validation Accuracy : 82.41 %
# Epoch 34/100 | Training Loss : 0.3355 | Training Accuracy : 83.74 % | Validation Loss : 0.3598 | Validation Accuracy : 82.07 %
# Epoch 35/100 | Training Loss : 0.3430 | Training Accuracy : 82.68 % | Validation Loss : 0.3613 | Validation Accuracy : 82.07 %
# Epoch 36/100 | Training Loss : 0.3439 | Training Accuracy : 82.82 % | Validation Loss : 0.3688 | Validation Accuracy : 82.07 %
# Epoch 37/100 | Training Loss : 0.3434 | Training Accuracy : 82.80 % | Validation Loss : 0.3599 | Validation Accuracy : 82.24 %
# Epoch 38/100 | Training Loss : 0.3511 | Training Accuracy : 82.18 % | Validation Loss : 0.3610 | Validation Accuracy : 82.07 %
# Epoch 39/100 | Training Loss : 0.3476 | Training Accuracy : 82.80 % | Validation Loss : 0.3607 | Validation Accuracy : 82.24 %
# Epoch 40/100 | Training Loss : 0.3398 | Training Accuracy : 83.28 % | Validation Loss : 0.3611 | Validation Accuracy : 82.07 %
# Epoch 41/100 | Training Loss : 0.3377 | Training Accuracy : 82.30 % | Validation Loss : 0.3624 | Validation Accuracy : 82.41 %
# Epoch 42/100 | Training Loss : 0.3448 | Training Accuracy : 82.26 % | Validation Loss : 0.3614 | Validation Accuracy : 82.07 %
# Epoch 43/100 | Training Loss : 0.3397 | Training Accuracy : 82.74 % | Validation Loss : 0.3584 | Validation Accuracy : 82.41 %
# Epoch 44/100 | Training Loss : 0.3395 | Training Accuracy : 82.80 % | Validation Loss : 0.3638 | Validation Accuracy : 82.07 %
# Epoch 45/100 | Training Loss : 0.3378 | Training Accuracy : 83.45 % | Validation Loss : 0.3625 | Validation Accuracy : 82.07 %
# Epoch 46/100 | Training Loss : 0.3473 | Training Accuracy : 82.15 % | Validation Loss : 0.3637 | Validation Accuracy : 81.72 %
# Epoch 47/100 | Training Loss : 0.3479 | Training Accuracy : 82.24 % | Validation Loss : 0.3633 | Validation Accuracy : 82.24 %
# Epoch 48/100 | Training Loss : 0.3452 | Training Accuracy : 82.80 % | Validation Loss : 0.3611 | Validation Accuracy : 82.41 %
# Epoch 49/100 | Training Loss : 0.3398 | Training Accuracy : 82.85 % | Validation Loss : 0.3695 | Validation Accuracy : 81.38 %
# Epoch 50/100 | Training Loss : 0.3424 | Training Accuracy : 83.22 % | Validation Loss : 0.3600 | Validation Accuracy : 82.24 %
# Epoch 51/100 | Training Loss : 0.3417 | Training Accuracy : 82.99 % | Validation Loss : 0.3614 | Validation Accuracy : 82.24 %
# Epoch 52/100 | Training Loss : 0.3400 | Training Accuracy : 83.01 % | Validation Loss : 0.3623 | Validation Accuracy : 82.24 %
# Epoch 53/100 | Training Loss : 0.3391 | Training Accuracy : 82.59 % | Validation Loss : 0.3694 | Validation Accuracy : 81.38 %
# Epoch 54/100 | Training Loss : 0.3395 | Training Accuracy : 83.49 % | Validation Loss : 0.3630 | Validation Accuracy : 82.24 %
# Epoch 55/100 | Training Loss : 0.3363 | Training Accuracy : 83.08 % | Validation Loss : 0.3619 | Validation Accuracy : 82.24 %
# Epoch 56/100 | Training Loss : 0.3398 | Training Accuracy : 82.99 % | Validation Loss : 0.3665 | Validation Accuracy : 82.07 %
# Epoch 57/100 | Training Loss : 0.3438 | Training Accuracy : 82.09 % | Validation Loss : 0.3672 | Validation Accuracy : 81.55 %
# Epoch 58/100 | Training Loss : 0.3352 | Training Accuracy : 83.28 % | Validation Loss : 0.3624 | Validation Accuracy : 82.24 %
# Epoch 59/100 | Training Loss : 0.3432 | Training Accuracy : 83.39 % | Validation Loss : 0.3604 | Validation Accuracy : 82.07 %
# Epoch 60/100 | Training Loss : 0.3418 | Training Accuracy : 83.12 % | Validation Loss : 0.3633 | Validation Accuracy : 81.90 %
# Epoch 61/100 | Training Loss : 0.3392 | Training Accuracy : 83.20 % | Validation Loss : 0.3608 | Validation Accuracy : 82.41 %
# Epoch 62/100 | Training Loss : 0.3418 | Training Accuracy : 83.20 % | Validation Loss : 0.3681 | Validation Accuracy : 81.55 %
# Epoch 63/100 | Training Loss : 0.3371 | Training Accuracy : 83.89 % | Validation Loss : 0.3619 | Validation Accuracy : 82.07 %
# Epoch 64/100 | Training Loss : 0.3388 | Training Accuracy : 83.43 % | Validation Loss : 0.3646 | Validation Accuracy : 81.90 %
# Epoch 65/100 | Training Loss : 0.3400 | Training Accuracy : 82.89 % | Validation Loss : 0.3610 | Validation Accuracy : 82.41 %
# Epoch 66/100 | Training Loss : 0.3414 | Training Accuracy : 83.03 % | Validation Loss : 0.3602 | Validation Accuracy : 82.24 %
# Epoch 67/100 | Training Loss : 0.3401 | Training Accuracy : 83.03 % | Validation Loss : 0.3656 | Validation Accuracy : 81.90 %
# Epoch 68/100 | Training Loss : 0.3396 | Training Accuracy : 82.87 % | Validation Loss : 0.3606 | Validation Accuracy : 82.07 %
# Epoch 69/100 | Training Loss : 0.3353 | Training Accuracy : 83.03 % | Validation Loss : 0.3636 | Validation Accuracy : 81.55 %
# Epoch 70/100 | Training Loss : 0.3364 | Training Accuracy : 83.16 % | Validation Loss : 0.3674 | Validation Accuracy : 81.90 %
# Epoch 71/100 | Training Loss : 0.3415 | Training Accuracy : 82.66 % | Validation Loss : 0.3624 | Validation Accuracy : 82.41 %
# Epoch 72/100 | Training Loss : 0.3426 | Training Accuracy : 82.59 % | Validation Loss : 0.3630 | Validation Accuracy : 82.76 %
# Epoch 73/100 | Training Loss : 0.3422 | Training Accuracy : 83.01 % | Validation Loss : 0.3647 | Validation Accuracy : 82.24 %
# Epoch 74/100 | Training Loss : 0.3504 | Training Accuracy : 82.72 % | Validation Loss : 0.3606 | Validation Accuracy : 82.41 %
# Epoch 75/100 | Training Loss : 0.3430 | Training Accuracy : 82.87 % | Validation Loss : 0.3624 | Validation Accuracy : 82.07 %
# Epoch 76/100 | Training Loss : 0.3413 | Training Accuracy : 83.16 % | Validation Loss : 0.3628 | Validation Accuracy : 82.07 %
# Epoch 77/100 | Training Loss : 0.3475 | Training Accuracy : 83.10 % | Validation Loss : 0.3625 | Validation Accuracy : 81.90 %
# Epoch 78/100 | Training Loss : 0.3502 | Training Accuracy : 82.97 % | Validation Loss : 0.3632 | Validation Accuracy : 82.07 %
# Epoch 79/100 | Training Loss : 0.3349 | Training Accuracy : 83.49 % | Validation Loss : 0.3604 | Validation Accuracy : 82.07 %
# Epoch 80/100 | Training Loss : 0.3409 | Training Accuracy : 83.47 % | Validation Loss : 0.3601 | Validation Accuracy : 82.41 %
# Epoch 81/100 | Training Loss : 0.3369 | Training Accuracy : 83.35 % | Validation Loss : 0.3649 | Validation Accuracy : 81.55 %
# Epoch 82/100 | Training Loss : 0.3410 | Training Accuracy : 82.87 % | Validation Loss : 0.3618 | Validation Accuracy : 82.07 %
# Epoch 83/100 | Training Loss : 0.3438 | Training Accuracy : 82.64 % | Validation Loss : 0.3628 | Validation Accuracy : 82.24 %
# Epoch 84/100 | Training Loss : 0.3402 | Training Accuracy : 83.28 % | Validation Loss : 0.3659 | Validation Accuracy : 81.55 %
# Epoch 85/100 | Training Loss : 0.3322 | Training Accuracy : 83.43 % | Validation Loss : 0.3651 | Validation Accuracy : 82.07 %
# Epoch 86/100 | Training Loss : 0.3431 | Training Accuracy : 82.85 % | Validation Loss : 0.3627 | Validation Accuracy : 82.59 %
# Epoch 87/100 | Training Loss : 0.3454 | Training Accuracy : 82.49 % | Validation Loss : 0.3616 | Validation Accuracy : 81.90 %
# Epoch 88/100 | Training Loss : 0.3366 | Training Accuracy : 83.43 % | Validation Loss : 0.3584 | Validation Accuracy : 82.41 %
# Epoch 89/100 | Training Loss : 0.3464 | Training Accuracy : 82.82 % | Validation Loss : 0.3617 | Validation Accuracy : 82.07 %
# Epoch 90/100 | Training Loss : 0.3482 | Training Accuracy : 82.87 % | Validation Loss : 0.3602 | Validation Accuracy : 82.41 %
# Epoch 91/100 | Training Loss : 0.3430 | Training Accuracy : 83.26 % | Validation Loss : 0.3603 | Validation Accuracy : 82.07 %
# Epoch 92/100 | Training Loss : 0.3441 | Training Accuracy : 82.78 % | Validation Loss : 0.3592 | Validation Accuracy : 82.76 %
# Epoch 93/100 | Training Loss : 0.3372 | Training Accuracy : 82.91 % | Validation Loss : 0.3652 | Validation Accuracy : 82.07 %
# Epoch 94/100 | Training Loss : 0.3374 | Training Accuracy : 83.39 % | Validation Loss : 0.3596 | Validation Accuracy : 82.24 %
# Epoch 95/100 | Training Loss : 0.3327 | Training Accuracy : 83.85 % | Validation Loss : 0.3625 | Validation Accuracy : 82.59 %
# Epoch 96/100 | Training Loss : 0.3390 | Training Accuracy : 83.85 % | Validation Loss : 0.3631 | Validation Accuracy : 82.24 %
# Epoch 97/100 | Training Loss : 0.3418 | Training Accuracy : 83.45 % | Validation Loss : 0.3628 | Validation Accuracy : 81.72 %
# Epoch 98/100 | Training Loss : 0.3358 | Training Accuracy : 83.51 % | Validation Loss : 0.3603 | Validation Accuracy : 82.24 %
# Epoch 99/100 | Training Loss : 0.3473 | Training Accuracy : 82.26 % | Validation Loss : 0.3615 | Validation Accuracy : 82.24 %
# Epoch 100/100 | Training Loss : 0.3374 | Training Accuracy : 82.68 % | Validation Loss : 0.3604 | Validation Accuracy : 82.24 %
# Test Subject : 9 | Test Loss : 0.2864 | Test Accuracy : 86.11 %
#
# ################################
#
# ================
# LOSO Summary
# ================
# Subject 0 -> Test Accuracy : 69.31 %
# Subject 1 -> Test Accuracy : 58.09 %
# Subject 2 -> Test Accuracy : 57.92 %
# Subject 3 -> Test Accuracy : 88.24 %
# Subject 4 -> Test Accuracy : 86.22 %
# Subject 5 -> Test Accuracy : 82.78 %
# Subject 6 -> Test Accuracy : 81.11 %
# Subject 7 -> Test Accuracy : 79.74 %
# Subject 8 -> Test Accuracy : 86.11 %
#
# -----------------------------
# Average Test Accuracy : 76.61 %
# -----------------------------
